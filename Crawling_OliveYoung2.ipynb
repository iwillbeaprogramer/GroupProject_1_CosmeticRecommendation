# %% [markdown]
# ### import문

# %%
import requests
from bs4 import BeautifulSoup
import json
import re
import pickle
import nltk
import sklearn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
stopWord = ['ㅋ',',','^','ㅠ','ㅡ','ㅎ']

# %%
def crawling_data():
    import pandas as pd
    df=pd.read_csv("data/naver_shopping.txt",delimiter='    ',encoding='utf-8',names=['내용'])
    data=df.values
    a=df['내용'].tolist()
    result=[]
    for i in a:
        temp = i.split("\t")
        result.append(temp)
    result
    for j in result:
        if int(j[0])>=3:
            j[0]=1
        else:
            j[0]=0
    return result

# %%
result = crawling_data()
result
# Out:
# C:\Users\kimsuhyun\.conda\envs\tensor_21\lib\site-packages\ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
# [[1, '배공빠르고 굿'],
#  [0, '택배가 엉망이네용 저희집 밑에층에 말도없이 놔두고가고'],
#  [1, '아주좋아요 바지 정말 좋아서2개 더 구매했어요 이가격에 대박입니다. 바느질이 조금 엉성하긴 하지만 편하고 가성비 최고예요.'],
#  [0,
#   '선물용으로 빨리 받아서 전달했어야 하는 상품이었는데 머그컵만 와서 당황했습니다. 전화했더니 바로주신다했지만 배송도 누락되어있었네요.. 확인안하고 바로 선물했으면 큰일날뻔했네요..이렇게 배송이 오래걸렸으면 사는거 다시 생각했을거같아요 아쉽네요..'],
#  [1, '민트색상 예뻐요. 옆 손잡이는 거는 용도로도 사용되네요 ㅎㅎ'],
#  [0, '비추합니다 계란 뒤집을 때 완전 불편해요 ㅠㅠ 코팅도 묻어나고 보기엔 예쁘고 실용적으로 보였는데 생각보다 진짜 별로입니다.'],
#  [0,
#   '주문을 11월6에 시켰는데 11월16일에 배송이 왔네요 ㅎㅎㅎ 여기 회사측과는 전화도 안되고 아무런 연락을 받을수가 없으니 답답하신 분들은 다른곳에서 사시는거 추천드립니다'],
#  [0, '넉넉한 길이로 주문했는데도 안 맞네요 별로예요'],
#  [0, '보폴이 계속 때처럼 나오다가 지금은 안나네요~'],
#  [0,
#   '110인데 전문속옷브랜드 위생팬티105보다 작은듯해요. 불편해요. 밴딩부분이 다 신축성없는 일반실로 되어있어 빅사이즈임에도 빅사이즈같지않아요. 입고벗을때 편하게 밴딩부분이 늘어나고 입었을때도 밴딩이 잡아주어야하는데 말이죠.'],
#  [1, '사이즈도 딱이고 귀엽고 넘 좋아요 ㅎㅎ'],
#  [0, '베이지 색 구매했는데 약간 살색에 가까워요'],
#  [0, '화면빨인가봐요;; 노란컬러가 돋보여요;; 저렴한맛에 그냥 씁니다'],
#  [0, '별루 ㅏㅛㅇ치ㅗ티ㅓ치ㅗ탛캏타ㅗ티ㅗ티ㅗ티ㅛ티ㅛ티ㅗㅗㅗ치ㅕ치ㅕ쳐ㅣ처ㅣ치ㅓ처ㅣ펴ㅣ쳐ㅣ치ㅕㅐㅛㅌ쵸ㅔ려ㅔㅎ'],
#  [1, '촉감도 좋고 무게감이나 핏도 편합니다'],
#  [1, '불멍하기좋고 사이즈도 너무 좋아요'],
#  [1, '재구매 친구들이 좋은 향 난다고 해요'],
#  [0, '실내에서 신는건지 몰랐어요'],
#  [1, '재구매 다 좋은데 하나가 이상하네요'],
#  [1, '가게를 운영하는 사장님께서 대신 구매 해달라고 하셔서 구매하게되었는데 가게에 달아놓으니까 이쁘네요'],
#  [1, '가성비 괜찮습니다 바퀴가 고정된다면 별다섯개짜린데...'],
#  [0, '화장이 깨끗하게 지워지지않아요 거품이생기고 오랫동안 문질러서 씻어내야하지만 세정력이 별로인듯해요'],
#  [0, '남자 애들 인데 너무 좋아요 유해성분없어 초등들도 바르기좋아요'],
#  [0,
#   '채집통이 결착이 안됩니다. 채집통이 결착이 안되서 커터칼로 결착 부분과 모서리 부분을 깍아 냈더니 겨우 결착이 됩니다.해당 부분은 제품 불량 이슈 같구요 보내시기 전에 최소한의 테스트는 하고 보내주세요.'],
#  [1, '재구매 늘 사는 흙이에요 팽이들이 젤 좋아해요 빠른배송 감사합니다'],
#  [0,
#   '처음 쓸때만 좋고 쓰다보니 의자뺄때 소리 계속 나요 그래서 붙이는부직포 덧붙였는데 여전히 끌리네요 비추에요 테니스공으로 살껄 이쁜거 산다고 이거 사서 후회되요'],
#  [0,
#   '배송기사나, 판매하는 회사나 불친절하고 불쾌합니다. 서비스면에선 최악이네요 제품은 그럭저럭 쓸만합니다. 싼게 비지떡 마인드부터 갖추고 장사하시길바랍니다. 이익에 눈'],
#  [0, '저렴해서 구매 했지만 바지 완성도 떨어짐~~^^;'],
#  [0, '사용이 불편하고 잘빠지네요ㅜ'],
#  [0, '양은 많은데 맛은 없었습니다'],
#  [0, '설치할때 전압이 넘 높아 퓨즈 나갔어여'],
#  [0,
#   '첨에받았을땐 너무튼튼하구 칸막이도있구 넘맘에들었는데요... 지금도맘에는들어요..근데....먼지가 먼지가 세상먼지다묻어요ㅠㅠ흑흑ㅠ 집에가만히 뒀는데도 먼지가다묻어있어요ㅠ 한번들고 그냥 모셔두었어요ㅜㅜ 까만색은 넘나비추입니다ㅠ 아이보리로살껄...ㅠ'],
#  [0,
#   '휴대폰 각이 잘 안나옴 노트9 사용 얇은 케이스 꺼도 잘 빠지지가 않네요 진짜 불편한건 각도가 조절이 너무 조금 된다는 점 입니다,,,,'],
#  [1, '너무 생각보다 고급스럽'],
#  [1, '가볍고 좋아요. 옵션에 파우치도 있었으면 얼마나 좋았을까 아쉽네요. 따로 구매 했어요. 잘 사용할께요.'],
#  [0, '총 4개 샀는데,사용하기 전에 부드러운 물티슈로 닦았는데,프린트가 번졌네요 교환하기가 귀찮아서 그냥 쓰지만 아쉽네요'],
#  [0, '모기가 않들어가요ᆢ'],
#  [1, '선물준사람도 받은사람도 모두 만족했어요^^'],
#  [0,
#   '예쁘고 심플해서 샀는데. 재질이 깔끄러워요. 살에 자국 다 베이고ㅠㅠ....폭망이에요. 재대로 확인안한 제 잘못이죠;;; 참고로 싱글세트 2. 퀸세트 1 샀습니다.'],
#  [1, '고정이 잘되기는 하는데 많이 쓰면 떡진것 처럼 보일까봐 걱정되서 많이 못쓰겠어요'],
#  [1, '맛있어서 주문합니다. 카페갈 필요없음'],
#  [0,
#   '진짜 너무하시네요 배송이늦는건 엄절수없다하고 참앗지만 밑에 서랍이 금방 안되서 AS되냐고 물어봣는데 전화도 안받고 10시에 톡을보냇는데 오후6시에 답해서 뭐하나물어보려고하니 상담시간이아니라고 뜨네요 빨리as좀 해주세요 안되면 안된다고 답장부탁드립니다'],
#  [1, '좋아요 색도 좋고 포근한 이불'],
#  [1, '네이비 색상이 조금 진한듯 하지만 굿'],
#  [1, '역시 기다린 보람이 있는 제품이군요!!'],
#  [0, '퀄리티 가 좀떨어지고 손이따로노는것 같아요'],
#  [0, '약간 삐뚤게 설치되네요.. 반품 귀찮아서 그냥 씁니다.'],
#  [0, '피부 트러블 더 많이 올라와서 몸에 사용했는데 몸에도 뾰루지나네요ㅜ'],
#  [0,
#   '겁나 아픈데 익숙해지면 된다길래 몇일 했더니 발에 멍들고 고통이 너무 심하고 컨디션이 더 안좋아져서 결국 패기처분 했네요. 사람마다 다르니 사기전에 신중히 결정하세요. 참고로 전 평발아닙니다.'],
#  [1, '아직 이유식 초기라 사용하지않았지만 후기보고 믿고 구매했습니다! 사이즈는 다양해서 너무 좋고요 실리콘재질이라 편하게 쓸거같아요'],
#  [1, '사이즈가 딱이에요!! 오자마자 쪄 먹엇는뎅 달디달아요'],
#  [0, '좀뻣뻣해서 애가 좋아하질않네요'],
#  [0, '생각보다 너무 작아서요 나중에 먼지먹는식물이나 넣어야겠어요 물건은 흠없습니다'],
#  [0,
#   '세정력이 약해요. 처음사용할 땐 세제찌꺼기가 없어서 좋다고 했는데 2/3 사용해보니 너무 안씻겨요. 지멘스랑 안맞는건지.... 다시 쓰던 고체형으로 갈아탔습니다.'],
#  [0, '흡착력이 너무 약해요..ㅠ 식판은 잘붙는데 이거는 애기가 자꾸 떼네요'],
#  [0,
#   '재구매 짱구오빠네 소개로 이용했는데 저번엔 괜찮은거 같아서 또 샀는데 기름만 엄청 오고 질겨서 다 뱉었네요.. 좋은상품주시지 고객한명 잃으셨네요 ㅠ 이제 이용안하려고요'],
#  [0, '연휴때 시켯더니 연휴때 시켰더니 한달넘어서 왓네요 연락도 없고 택배회사도 연락없고 상품은 좋으나 너무 늦게와서 별로네요'],
#  [1, '저번에 쓰던게 망가져서 삿는데 역시 핸들돌릴때 편하네요'],
#  [0, '빠른 배송과 친절한 설명'],
#  [1, '빠른 배송 짱짱'],
#  [1, '오돌뼈 최고네요.. .'],
#  [0, '안에 패드가 자꾸 빠져서 불편합니다'],
#  [1, '재구매 가게에서 사용중입니다. 안주디피할때 이쁩니다.'],
#  [1, '큰사이즈를 구매해서 언제 끝낼지는 모르겠지만 프린트도 선명하고 좋아요!'],
#  [1, '너무예뻐요 포인트로딱이네요'],
#  [1, '보온 기능이 짱 최고입니다 강추'],
#  [1, '시간이 지나도 접착력이 그대로예요~~'],
#  [1, '괜찮네yo!'],
#  [0, '지퍼 한번쓰고 고장남 최악'],
#  [0, '무게가 많이 나가요 연마제 닦느라 애먹었네요'],
#  [0, '신중하게 선택하세요.'],
#  [0, '가격대비 너무 허접해요..쌓아놓으니 앞으로 기울고..내구성이 5점이기에 믿고 구입했는데 생각만큼 튼튼하지는 않네요'],
#  [1, '흰색이라 깔끔하고 아기쓰는건데 재질도 좋고 부드럽네요'],
#  [1, '항상 애용해서 ㅋㅋㅋ리뷰남기기도뭐하네요ㅋㅋ이것만 먹어요 배송도 빨라요'],
#  [1, '아주 편하진 않아요 밑위가 좀더길면 편할텐데'],
#  [1, '수딩젤만 바르면 오히려 더 건조해지는데 크림까지 발라주니 보습 잘 되고 좋아요'],
#  [1,
#   '믿고쓰는 페넬로페^^ 세자린쓰다가 새로 나온 제품이라서 구매했어요ㅎㅎ 세자린 마지막 팩쓰고 있는데, 떨어지기 전에 도착했네요^^'],
#  [0, '실망이네요 마무리처리가 너무엉성합니다'],
#  [1, '한사이즈 크게 시켰는데 잘 맞아요ㅋㅋㅋ'],
#  [1, '재구매 3통짼대 아주좋네요!강추'],
#  [1, '5센치 토퍼 사용하는데 사이즈 잘 맞고 좋았아요. 배송은 좀 늦게 왔네요...'],
#  [1, '좋아요~ 몇번을써도괜찮은거같네요'],
#  [0, '재구매 환불건 처리해주세요.'],
#  [1, '두께감도 적당하고 생각햇던것보다 더 괜찮아요. 다음에도 갈색으로 사야겟어요.'],
#  [0, '빠른 배송은 마음에 드는데 사진과 다른 증정품을 주셨네요. 변경 되었으면 미리 고지해주셨으면 합니다.'],
#  [1, '재구매 항상믿고구매하는곳이라...ㅋ 가격대비최고죵~~ 싸비스두최공~~'],
#  [0, '바람이 나는지 잘 모르겠네요'],
#  [0, '크기도 생각보다 크고요.심이 있어 쪄서 갈아 먹었는데도 안갈린건 입안에서 걸리더라구요.'],
#  [1, '선물로보냈는데 잘받았되요'],
#  [1, '필수입니다 꼭 같이 구매하세요'],
#  [0, '촉감 너무꺼끌하고 별로예요 시원한지도 잘모르겠고 반품귀찮아서 그냥씁니다'],
#  [1, '여유있게 보내주셨네요 잘쓸게요'],
#  [1, '가성비 최고 불도 밝고 이뻐요'],
#  [1, '여기상품좋다는지인추천에주문해봣는데 꾸준히써볼께요'],
#  [1, '재구매 회사에서 쓰는거라 자주 주문하고있어요. 좀 빨리 떨어지는거 같긴한데.. 그냥 쓰고 있어요. 배송은 빨라요'],
#  [1, '설치도 쉽고 화질도 좋고 넘 좋네요'],
#  [1, '아기목욕시키는데 잘쓰고 있긴한데 안전바는 잘안쓰게되네요 그리고 세면대에 설치한 시트는 밑에 고정다리가 좀 불안하네요'],
#  [1, '재구매 배송빠르고 너무만족해용~'],
#  [1, '배송도 빠르고 상품도 사진하고 똑같았어요'],
#  [0, '무게를많이 지탱을못햎자꾸 내려가네오 ㅠ'],
#  [0, '생각외로 모기가 안잡혀요'],
#  [0,
#   '고구마가 외이케 말랏나요 저나하려다 바빠깜팍 햇는데 서너번 주문한적잇는데 이런적업엇는데 그리고사이즈가 이정도면 중 이 아니라 긴 중 아닌가요'],
#  [0, '(바코드가 왜 손상되서 오는건지 알려주세요) 10년 넘게 써오던 제품이라 항상 만족합니다:)'],
#  [1, '대용량 박스 사이즈 잘 체크하고 사세요 많이 큽니다'],
#  [1, '시원하구 좋아용!!'],
#  [1, '제품주 좋지만 특히 배송날짜 칼이네요 이사간날 정확하게 배달 설치해주시구 감사합니다~~'],
#  [1, '늘 쓰던것~~여름이라 그런지 지속력이 좀떨어지네요ㅜ'],
#  [1, '가격이 저렴합니다 ㅎㅎㅎ'],
#  [0, '상품가치 없는크기를 보내셨어요 한입사이즈크기에 3/1은 상했구요 이건좀 아니다싶네요 정가에서 할인액은 크던데.'],
#  [0, '쓸데가 하나없음 효과일도없음'],
#  [1, '저렴하게 받아서 기분은좋아요 근데 가방에 실리콘 같은게 좀 묻어있더라구요.. 그거말고는 괜찬은거같아요'],
#  [1, '빠른배송감사합니다. 역시 헤라가 짱입니다~^^'],
#  [1, '받자마자 아이랑 같이 아이스크림 만들어먹었는데 실리콘으로 되어서 빼기도 편하고 좋았어요'],
#  [0, '어이가없네요 셈플한개가 비어서 왔네요'],
#  [0, '작업하기까다로움 효과도 체감안됨'],
#  [1, '만족합니다. 슬림핏 아닌 레귤러네요'],
#  [1, '왜 승무원 스프레이라고하는지 알겠네요 짱이에요. 흡수력 광택 @@'],
#  [1, '연어초밥, 연어장 만들어 먹었는데 너무 맛있어요! 내일은 연어 스테이크랑 까나페 해먹으려고합니다'],
#  [1, '상판이 조금 약하긴한데 일부러 누르지 않는한 크고 좋아요.'],
#  [1, '시원해서 잘쓸거같아요 여름에!'],
#  [1, '배송이 빨랏어요. 매번 먹단거랑 싼가격에 빨리 샀어요... 빠른배성 감사합니다'],
#  [0, '머리결은 트리트먼트 오래한거 치고는 그냥그럼, 탈색을 하지 않은 밝은 갈색모인데 파란색이 전혀 안입혀짐'],
#  [0, '핀부분만 골드라서그런지 이쁘긴한데 알러지반응이 있네요ㅠㅠ'],
#  [1, '나름튼튼하고 잘쓸수있을것같습니다 이가격에 이퀄리티면 훌륭하죠'],
#  [0, '배송느림.. 레깅스 밑단 마무리 엉성함.. 수트화면보다 밝음..주황색같아요'],
#  [1, '배송이 좀 느리고 상자에 제품만들어있네요 사용설명서가없어요 남자는 상관없지만여자분들은난감할수도 있겠네요'],
#  [1, '딱맞고 이뻐용'],
#  [0, '내구성 약함 입는데ㅇㄷㅇㅈㅇㄷㄱㅌㅅ 찢어짐ㄷㅇㄷㅇㄷㄱ딛승ㅌㄱㅈㆍㄷ능ㄷㅇㄷㄴ디ㅣㅡㅡ슴ㄷㅅㄷㅅㅈㅅㅈㅅㅈㅅㅈㅅㅈ'],
#  [1, '상품은 맘에 드는데 배송기간이 늦네요'],
#  [1, '두께감에 놀랬어요~ 도톰하니 좋아용'],
#  [0,
#   '완전 별로에요ㅡㅡ 사용법도 중국어랑 영어밖에 없구요 심지어 사이트에 올라온 사용법이랑도 다르네요 며칠 쓰다가 짜증나서 그냥 버렸어요'],
#  [0, '어떤 용도로 사용하는 목적인지... 알람 소리가 너무 작네요ㅠ'],
#  [0, '재구매 너무 크네요.. 진짜생각보다 너무큼'],
#  [1, '굿 몇년째 이것만 쓰고있어요 배송도 빠른편이고 좋습니다 근데 전보다 좀더 금방 쓰는것같네요 더 무른편인것같아요'],
#  [1, '선물용이라 꼭꼭 숨겨 놔서 아직 못봤어요..아이 마음에 들길.'],
#  [0,
#   '3개를 시켜서 1개는 제가 잘들고 다녔어요. 두개는 아이들용으로 샀는데 빨간건.아예 로고조차 없네요 불량인지 뭔지 ㅡㅡ 이게 뭔가요? 검수도 안하고 보이시나요? 제가 바빠서 이제서야 봤더니 너무 놀랬네요 ㅡㅡ'],
#  [0, '칸막이 규격이나 높이가 딱맞지 않아서 들고 다니면 물건이 섞임 ㅜ'],
#  [0, '성의없는 제품포장상태보고 다시는 구입하고자 하는마음이생기네요...'],
#  [1, '맛나네요, 좋아요~~~~'],
#  [1, '너무너무 착붙 레깅스네요 다른색상도 샀어야했는데 담번에 나오면 꼭 추가구입합니자'],
#  [1, '겨울에 촉촉하게 커버돼요'],
#  [0, '배송이 아주아주 느려서 행사 다 끝나고나서 배송받았네요'],
#  [0,
#   '용량이 10000짜리가 맞는지 좀 의심스러워요 노트7 20퍼 충전했는데 1칸이 사라져버리네요 무선 연결되는데 시간도 좀 걸리고 유선충전하는데에도 충전기에서 무슨 소리가 나요 그래도 깔끔하고 사용하는데 별로 지장은 없습니다'],
#  [0, '배송 서비스 매우 안좋음 (일방적인 스케줄 통보, 안되면 배째라식)'],
#  [1, '처음 먹어보는데 맛있어요.생각보다 작긴했는데 비리지도 않고 잘먹었어요'],
#  [0, '붙이기 정말 어렵습니다 둘다 버렸어요.... 다시 생폰상태입니다'],
#  [1, '울아이가 넘 좋아해요'],
#  [1, '배송이 느린거 빼고는 싱싱하고 맛있어요'],
#  [0, '생각보다 흡수력이 좋진 않아요~~'],
#  [1, '장말좋아여 엄마아빠도 써보니까 좋다고하시네요 ^^ 다 쓰고 나면 재구매할게요 많이 파세요 많이 번창하세요'],
#  [0, '한쪽면이버겨져서녹이슬고끈적이임심합니다'],
#  [0, '돈이조금아까운상황~~'],
#  [0, '볼트도 안맞고 찌그러져서 배달오고 별루임'],
#  [0, '쓰다보니 그냥 싼이유가 있습니다. 흉터와 반응이 없네요'],
#  [1,
#   '포장도 하나하나 포장해주시고^^ 다른곳은 레드장몽이라 판매해서 구매해보면 레드가 하나있고 나머지는 전부 레드가 아닌데 여긴 전부 싱싱하고 올레드입니다,, 재구매합니다~~~당도도 좋아요'],
#  [0, '지속력만 좀 좋으면 너무 좋을가 같아요'],
#  [1, '접이식이라 수납좋고 가방까지 있어서 좋네요 다만 철가방에 잠금고리 하나 있었으면 더 좋았을듯'],
#  [0, '재구매 밤을 20키로를 시켜먹었는데 마지막 4키로 시킨건 왜이런가요???너무 상한게 많아요 짜증나네요'],
#  [1, '대형마트에서 구매를 한다고 발품을 팔다가 네이버페이에 좋은 상품이 있어서 너무 좋았어요! 잘 쓸게요!^^'],
#  [0, '제가잘못미는건지 때가 잘 안나오고 그냥 때국물처럼 나오네요 ㅠㅠ'],
#  [1, '마음에 들어요 ㅎㅎ 마음에 드는데 생각보다 크기가 너무 작아서 당황했어요 ㅠㅠ 그래도 다음에 또 구매할게요!!'],
#  [1, '재구매 좀 짧은듯하여 걸어두니 늘어나서 좋네요 편하게 롱롱치마원해서요'],
#  [1, '아직먹어보지않아가지고 일단배송은빠르고내용도깔끔하게왔어요'],
#  [0, '절대 안 살겁니다 후회해요.'],
#  [0,
#   '고급세트 시켰는데 가리비는 하나도 안들어있었고 너무 실망스러웠습니다.. 백상합은 1키로 추가했는데 괜히 했네요 문의글 남겼지만 답이 없어 리뷰로 남겨요'],
#  [0, '닭 특유의 비린 맛이 나서 별로요 ㅠㅠ'],
#  [0, '침대밑에 수납하기 좋은 사이즈네요'],
#  [0, '싱크랑 잘 안 맞아서 문이 잘 안 닫혀요'],
#  [0, '양도적고 신선도도별로예요ㅠ'],
#  [1, '무난해서 좋습니다,.'],
#  [0, '미스크가 없어서 주문해서 쓰긴 하네요 예전엔 무지 쌌는데~'],
#  [1, '좋아요 ㅎ 벤치들때쓰려고샀어ㆍ오'],
#  [1,
#   '착오로 인한 오배송건을 친절하게 상담해주시고 신속하게 재배송해주셨네요 상품의 빠른 배송과 훌륭한 품질이 아주 만족스런 거래였습니다'],
#  [1, '보들보들하고 44사이즈 답게 나왔어요. 잘어울려요'],
#  [1, '배송하루 더걸렸지만..늘 감사히먹고있습니다'],
#  [0, '목뿌러진게왔네요.. . 검수잘해달라고 부탁드렸는데ㅠ'],
#  [1, '재구매 잘먹고있습니다 아침식사로좋아요'],
#  [0, '비개 가 너--무 많아요'],
#  [1, '입구가 조금 좁은거 말곤 재질이나 배송 모두 만족합니다'],
#  [1, '재구매 좋아요 잘받았습니다 잘쓸께요'],
#  [0, '물건은 좋은디 아직 몰르겠고 배송은 빵점이네요 개봉하자마자 질질'],
#  [1, '배송 빠르게 잘받았습니다..저렴하게 필요한 제품 잘 구매한것 같네요.'],
#  [1, '배송이 빠르고 밝고 좋습니다'],
#  [0, '싼맛에 먹어요 ㅋㅋㅋ'],
#  [0, '택배가 너무느려요'],
#  [0, '앞으로 당겨서 앉을때 잘 넘어지겠어요~~신중하게 골랐어야 했는데..'],
#  [0, '그다지 마음에 들지 않습니다.'],
#  [1, '신랑이 마음에 든다고하네요'],
#  [1, '좋아요 포장 뾱뾱이 잘싸져서 안전하게옴'],
#  [1, '맘에 들어 재구매 완료함~^^'],
#  [1, '재구매 늘쓰던건데 물티슈랑섞어서주니넘좋아서 또구매'],
#  [1, '말로만 들었던, 파워콤프에 앉아보니,, 아,, 왜 인생안장이라고 하는지 알것 같습니다. 강추합니다. 많이 파세요'],
#  [1, '게타로봇 찾았는데 만들기도 쉽고 재밌습니다. 잘만들었습니다.'],
#  [1, '빠른배송에 늘 만족'],
#  [0, '생각보다 색깔이 사진과 달랐습니다 발림성은 나쁘진 않아요 그치만 잘 사용해볼께요'],
#  [1, '기대한만큼 좋은소금.'],
#  [0, '색상이조금아쉬워요베이지'],
#  [1, '이시기에 배송도 빠르고 좋은것 같아요~'],
#  [0,
#   '재구매 불량품이 너무 많아요 매번 주문했었는데 이번에는 실망스러워요 테이프가 끊어지는 경우도 많고 접착도 잘 안되고 불량이 너무 많네요'],
#  [0, '흡착 고무 수량 부족 및 불량'],
#  [0, '에어가 조금씩 빠지는게 아쉽네요'],
#  [0, '아이가 좋아하네여~'],
#  [1, '약간 너무 편해보이긴 한데 너무 시원해서 매일 입을듯'],
#  [0,
#   '재구매 소갈비탕하고 같이 주문했는데 제육은 녹아와서 실망이네요 맛도 고기도 좀.. 갈비탕보다는 덜하네요 밥에 비벼먹기 한끼로는 이가격에 괜찮아요'],
#  [0, '무늬가 지워지면서 옷에 이염되네요.'],
#  [1, '재구매 거래처에 항상 구매해요'],
#  [1, '재구매 아이들 간식으로 좋아요~'],
#  [1, '배송도 빠른편이고 우산크기도 좋긴한데 우산접었을때 체결하는 부분이 너무 뻑뻑하네요'],
#  [0,
#   '상품평을 보고 맛이 없다는걸 알고 샀으나..맛이 없긴하네요~아이가 먹어보고 싶다고 해서 샀는데..안에 액체만 쏙~먹고 병모양은 몇번 씹어보더니 인제 씹지도 않아요..ㅋㅋ 한번쯤 재미로 샀다고 생각하고 넘어갈려고해도 가격이 비싸긴해요~^^;;;'],
#  [1, '아직 교체전 그러나 다 비슷하겠지'],
#  [0, '젓가락좀넣어주시면좋낫을템데'],
#  [0, '빨대 또 그러네요'],
#  [1, '빠룬배송 다양한 사이즈 너무 좋아요'],
#  [0,
#   '전체 바디가 끈적끈적해서 옷을 안걸어두면 옷걸이들이 서로 막 달라붙습니다 옷걸이가 너무 뭐랄까 끈적여요ㅎㅎ 예민하신 분들은 참고하세요'],
#  [1, '너무 맛있어요 나중에 또 재구매하고 싶어요'],
#  [1, '좋아요 불멍때렸어요 ㅎㅎ'],
#  [0,
#   '배송느립니다. 오전7시이전에 주문해야 당일 발송합니다. 목욜 오전8시반쯤 주문하니 화욜에 받았습니다. 배송속도관계없는분 추천합니다. 상품에 문제가 있는건 아니니까요.'],
#  [0, '특상을 주문했는데 중간사이즈가 많아요. 종이컵안에 쏙 들어가는 사이즈도 많이 들어있어요'],
#  [1,
#   '가성비 굿이에요 저는 프레임만 구입했는데 2주만에 왔고요 디자인 깔끔하고요 인터넷 다른상품들과 비교해도 가성비 좋아요 배송해주시는분도 친절했고요 그리고 저상이라 좋더라고요'],
#  [0, '배송도 한달걸린거같고...제품도 그닥....'],
#  [0, '작은 사이즈 필요해서 구매했어용'],
#  [0, '3마리중 1마리만 크고 나머지는 쪼그마한 것이 와서 조금 실망햇네요... 중으로 주문했는데'],
#  [0, '처음에는 몰랏는데 신고나서 보닌깐 리본묶을라고 봣더니 한쪽이 리본이 당겨지지가 않아요... 다음엔 확인잘하고 보내주세요'],
#  [1, '매우 만족합니다 재구매 의사 있어요'],
#  [0, '분무기가 질질 새여~~~~ㅜ 원래그래요?'],
#  [0, '제품이 잘못 왔어요 문의까지하고 주문했는데..'],
#  [0,
#   '리뷰가너무좋아서 구매했어요.외관케이스랑은 너무깔큼하고있는데 치약이좀쓴편이에요.첫맛부터끝까지쓴맛이너무써서 저랑신랑아이들이랑은안맞는거같아요ㅜㅜ'],
#  [1, '곱창 냄새안나고 양념도 맛있고 양도 많네요 포장도 꼼꼼하구요~'],
#  [0, '분무기 윗 부분이 손상이 되어있어는데 그래도 사용하는데 지장이 없어서 그냥 사용할게요'],
#  [1, '생각했던 데로 편하고 좋습니다.'],
#  [0, '유액바르는 허접한 종이조각 색바랜 밑그림 최악입니다'],
#  [1, '상품 good 배송 good'],
#  [1, '엄청 앏지않고 좋음'],
#  [0, '생각보다 넘질겨요 부채살이 훨씬낳아요'],
#  [1, '입자가 고와요 양치후 입이 개운해요'],
#  [1, '좋아요 무겁지도않고 마스크 안잃어버리고좋아요'],
#  [1, '분말이 고아서 쓰기좋아요 아이 양치질용으로 아이 사탕용으로 잘 쓰고 있어요 감사합니다^^'],
#  [0,
#   '박스를 열었을때는 알이 굵고 애기 머리통만한 고구마라 좋아라했어요. 구워먹으려고 자르는 순간 표면이 까맣게 변했고 굽고 나니까 속이 까매진게 보이네요. 단맛도 안나고 약간 쓴맛 같은게 나서 속상하네요.'],
#  [0,
#   '의자 4개 다리 중에 짧은 다리가 하나 있고, 그결과 레벨이 맞지 않아 한쪽으로 기우뚱 거려 앉아있기 불편합니다. 교환해주세요!'],
#  [1, '재구매 부드럽고 좋네요^^'],
#  [1, '다른거 주문하면서 볶음용이 없어서 주문했는데 편하고 좋아요!'],
#  [1, '너무 괜찮네요. 다른색상 하나더 구입할 예정입니다.'],
#  [0,
#   '사용할때마다 삐그덕소리가 너무심해 동봉된 윤활유를 발라봤는데도 소리가 너무 나네요 절대 추천하지않습니다 사지마세요 운동할때 신경쓰여서 쓰도못합니다'],
#  [1,
#   '재구매 편의점에서 작은 상자에 들어있는걸로 먹어봤는데 너무 맛있어서 직접 검색해서 벌써 세번째인가 그러네요.,.,^^ 먹을때마다 맛있고 질리지않는 맛이라 너무 좋아요.,'],
#  [1, '카르티닌 덕분에 땀은 엄청 잘나네요'],
#  [1, '재구매 역시 리챔~~~싸게 잘 사서 좋네요'],
#  [0,
#   '털이 너무 빠집니다..처음 세탁을 할때 털이 세탁물에 다 묻어서 기겁을 했는데 두번째도 역시 많이 빠지길래 저와는 안맞는다 생각합니다.'],
#  [0,
#   '가운데 딱 고정이 안되요.. 장거리 다녀오면서 착용했는데 아이가 움직이니 버클이 아래로 내려가면서 가슴쪽 줄이 목을 감싸더라구요..ㅜㅜ 가까운 거리 사용시는 괜찮아요'],
#  [0, '조개 내용물이 너무 작아요. 아쉽습니다.'],
#  [0, '배송은 시간딱 맞춰서 5일만에 와주셨네요 사이즈가 약간 작은부위도있는데 티어나오는 부위가 있네요..'],
#  [1,
#   '지방이라서 배송이 늦을줄 알았는데 배송도 빠르고 제품도 생각한것처럼 예쁘고 깔끔해요 특히나 배송 기사님이 넘 친절하셔서 너무 좋았어요'],
#  [0, '상품은 늘 쓰던거라 구매했는데요 제조일자 6개월이상 된거 보내주셨네요 기분 나쁩니다'],
#  [0,
#   '고들빼기라 되있는데 깻잎이?? 제가 깻잎을 좋아하고 가격도 비슷하고 귀차나서 다시 환불이나 교환요청은 안합니다만 이렇게 파시면 안되죠...다신 이러지 않으시길'],
#  [0, '붓기 넘넘 잘빧아요'],
#  [0, '물건을 얼려놓으면 앞으로 다쏠리고 힘아리가 하나도 없네요'],
#  [0, '신맛이 나요.. 무친지 좀 오래된듯해요.. 산거 후회합니다. 다 버려야 할듯 해요'],
#  [0, '물빠짐 물빠짐 심합니다 실보프라기도 심해서 한참 제게했고 중간중간 올플림도 있어요 가격대비 별로예요'],
#  [1, '소리도 잘나오고 가성비 정말 좋네요 드라이브 기능도 있어서 너무 만족해요'],
#  [0,
#   '정전기 대박.... 길이가 긴건 내 키가 작아서라고쳐도 정전기는 왜이렇게 심한건지 만지기만하면 따닥따다닥 거리고 다리에 다 들러붙고 !! 이런옷처음 사봤네여.. 세탁후에도 이러니 어찌입어야되는지ㅜ'],
#  [1, '맛있고 고급스러워보입니다'],
#  [1,
#   '좋아요 아이 연습용으로 구매했습니다 저는 바이올린은 아예 몰라서 유튜브영상으로 송진바르는법 이랑 튜닝법 검색했어요 송진도 주시고 여분 줄이랑 바이올린 거치대까지 주시고 좋네요!!! 잘 사용할게요~'],
#  [1, '열전달도잘괴고좋습니다'],
#  [0, '너무 크네요 생각보다 크게 나오니 주의하셔요'],
#  [0, '남편 선물로 사줬는데... 하루만에 벗겨졌어요.... 비추입니다'],
#  [0, '필터 마크가 두칸밖에안뜨요.정품맞아요'],
#  [1, '괜찬습니다^^ 잘쓰고있어요'],
#  [1, '배송 빨랐어요 좋습니다'],
#  [0, '상품은 이쁜데 갓이 다 찌그러져서 왔어요 포장을 좀더 신경써주세요'],
#  [0, '배송이 넘 느리네요..'],
#  [0, '앙고라 털이 엄청빠져요 옷에 다 붙어나와요'],
#  [1, '예쁘고 깔끔 아부조아요'],
#  [1, '가서사는것보단 저렴한듯. 좋아요'],
#  [0, '재구매 항상쓰던제품 입니다'],
#  [0, '너무 써요 ㅠㅠㅠ 왠만해서 잘먹는데 표정이 막 일그러져요 ㅠㅠ'],
#  [1, '매번 쓰는거예요 촉촉해요'],
#  [0, '다른 제품 사용시 전력 달려서인지 깜박거리네요'],
#  [1, '괜찮은데 손이 작아서 ㅎㅎㅎ 그래도 좋아요 편해요'],
#  [1, '배송이 빠르고 깔끔한 포장이예요'],
#  [1, '운동화 220 사이즈 신는데 230주문 했더니 작아서 교환 했어요.'],
#  [1, '배송은 좀 늦었지만 바지는 좋아요 그래서 다른 사이즈로 두벌 더 구매하려고 합니다'],
#  [1, '싸게 잘산듯 좋아요 많이 파세요'],
#  [0, '리뷰순보고 삿는데 그닥이요....'],
#  [0, '가격대비별로애요 괜히삿어요'],
#  [1, '빠르게 잘받고 그럭저럭 쓸만 합니다'],
#  [1, '색상초이스를 잘못했어요. 블랙한다는걸ㅠㅠ 그래도 잘쓸게요'],
#  [0, '처음 한 봉지 뜯자마자 머리카락 발견....'],
#  [0,
#   '전 별로~ 신혼때 유리로된거 잘붙는거 사서 잘 썼거든요~ 이사오면서 두고와서 새로사야지 하고 봤더니 그런건줄 알았더니 붙이니까 다 울어요 완전 얼굴이 꿀렁거려서 멀미나요 ㅜㅜ 대충 쓰다가 다음에 이케아에서 유리로된거 살려구요'],
#  [1,
#   '좋아요 킹사이즈 침대에 ss사이즈크기로 샀어요 딱 맞는게 좋아서 그렇게샀는데 오늘 세탁하기전에 살짝 깔아보니가 예쁘게 딱 맞아요 ^^'],
#  [1, '스텐이 견고해 보이고 붙이기도 간단하고 좋아요'],
#  [0, '천이 천막천보다얇아요 날씨추워지면 찢어질것같아요'],
#  [0,
#   '중간사이즈가 중간사이즈가 아니고 완전 소자입니다. 대자하고 같이 주문했는데 너무 작아서 서비스인줄 알았다가 깜짝 놀랐습니다. 박카스 뚜껑 크기도 안됩니다'],
#  [1, '커피는 top 덤으로 싸다 배송 빠르다 이상'],
#  [0, '아직 몇일 안써봐서 잘은 모르지만 이틀째부터 트러블이 더 심해진듯 해요. 일주일 써보고 계속쓸지 고민 해 봐야겠어요'],
#  [1, '한장씩 뽑아쓰니까 너무 편리합니다.'],
#  [0,
#   '관절베이트 인데 관절이 움직이질 않네요 관절사이랑 베이이트 옆구리등 코팅제가 뭉쳐서 굳어있습니다 그냥 싸니까 고쳐서 써보긴 하겠지만 사업이 번창 하시려면 싼제품 이라해도 좀더 신경을 쓰셔야 될거 같네요'],
#  [0, '다 녹아서 왔습니다. 색도 갈변되어서 왔구요...'],
#  [0, '블랙사각 4호 주문했는데 화이트 사각 3호가 왔어요 바로 교환신청했는데도 2주 넘게 걸리고 짜증났어요'],
#  [1, '재구매 맛이 좋아 항상 여기서 주문해서 먹고 있어요^^'],
#  [0,
#   '여기 의자를 다시 사는 일은 없을겁니다. 의자 그 자체로는 괜찮지만 배송상태와 여기져기 긁힌걸 그냥 주는건 새상품을 파는방법이 아니라고 봅니다.'],
#  [1, '아들이 따뜻하고 가볍다고 합니다 ~^^'],
#  [1, '튼튼하고 졸습니다 잘 사용하고 있어요'],
#  [0, '아직 세제는 써보지 않았어요. 섬유유연제는 저에겐 향이 너무나도 진합니다. 100원짜리동전만큼 넣고 사용하고있습니다.'],
#  [0,
#   '솔직히 왜 샀나 싶네요. 너무 부드러워 씻기는 지 모르겠고 발바닥만 문질러질 뿐 발옆은 손으로 해야 해서 그냥 예전처럼 발전체를 손으로 하는 것과 같아요. 게으름 피우려던 나의 꼼수가 부끄럽네요.'],
#  [1,
#   '무조건 곡ᆢ 고민하지말고 구매하세요ㅋㅋ 배송은 해외배송이고하니 좀 느리지만 조급해말고 기다리시면 도착해요ㅋㅋ 삼사일 사용중인데 피부넘 좋아져요~^^ 세안시 필수~~!!'],
#  [1, '재구매 발림성도좋고 크게 트러블도없어서 재구매햇어요'],
#  [1, '잘쓸께요잘써볼께요오오'],
#  [0,
#   '벌써3번째구매인데이번에받아본아로니아색깔이진하지않고덜갈았는지돌처럼씹히는게너무많네요..맛도쓰구요..판매자에게문의했더니사진찍어서올려달라고하는데기분이좀나쁘네요..'],
#  [0, '별로예요 재구매안해요'],
#  [0, '사은품은없네요?'],
#  [1, '조명이 엄청 환해서 거울이 눈부시고 양쪽이 접히는게 너무 맘에 듭니다.신기해서 샀는데 너무 좋네요.^^'],
#  [1, '이쁘게 포장되어 도착했네요~ 맛도 새콤하니 좋아요 음료수 대용으로 마시면 건강도 챙기고 좋을 것 같네요! 많이 파세요~'],
#  [0, '베어링 손잡이부분이 부러진상태로 배송됬네요...'],
#  [1, '이쁘고 시원하게 쓸수있을꺼같네요 ㅎ 근데 플라스틱 냄새는좀 나네요 시간지남 빠지겠죠'],
#  [0,
#   '활이요 .... 다 들뜨고 은색 불량인데요 활도 다 안채워져있어요. 불량인거면 교환해주시고 이걸 파시는거면 .... 휴 ... 답변 부탁드려요'],
#  [1, '가방 수납장으로쓰는데 튼튼화고 좋네요'],
#  [0, '원래 기기에서 소리나는 건가요??? 제품을 들때 이상항 소리나길래 촬영하였습니다. 연락주세요.'],
#  [1, '비싸요..맛잇네요 번창하세요'],
#  [0, '고기가 많이 질겨요'],
#  [1, '암막기능은 탁월한데 색상이 그냥 어두운 그레이네요ㅠ'],
#  [0,
#   '에어팟2 때문에 샀는데 연결시 음질이 많이 안 좋습니다 2g폰으로 통화하는 느낌 많이 끊기기도 하고 피치도 낮게 들리기도 하구요'],
#  [0, '지금 받아서 뜯어봤는데 내용물도 흘러있고 스틱이 엄청 빵빵해져있네요 내영물이 변질된건 아닌지 걱정입니다'],
#  [0, '몇번쓰고 생각보다 빨리 겉이 까져버려서 좀 그랬네요'],
#  [1, '지ㅡㄹ사용했ㅅ븨니다'],
#  [1, '향기 너무 좋네요. 아이도 좋아합니다. 주변 아이 엄마들한테 효과있다고 추천받아 샀는데 잘 산 것 같아요.'],
#  [0, '상품평이 좋아서 샀는데 품질은 가격 만큼이네요 허리를 지지하는곳이 플라스틱이다보니 좌우로 흐느적 거립니다. 솔직히 불편하네요'],
#  [1, '가성비 배송 제품 다만족입니다'],
#  [0,
#   '어떻게 문자 한통없이 택배가 오나요,, 심지어 아직까지 배송중 ^^ ㅋㅋ.ㅋㅋㅋㅋ.ㅋㅋㅋㅋ.ㅋㅋㅋㅋ.ㅋㅋ.ㅋㅋ 썪은 아보카도 잘 받았습니다~'],
#  [1, '좀비싸지만 좋아여 화장대에두고 머리감은직후 두피사용중'],
#  [1, '재구매 아직받진않았지만좋습니다'],
#  [1, '전체적으로 대가 약해보임 가격에 비해 수납공간은 괜찮았습니다'],
#  [0,
#   '귓볼 두꺼운 사람은 못쓰는 제품입니다. 성인남자 함으로 세게 눌렀는데도 끝까지 안뚫리고 귓속 중간에서 멈추네요... 여러번 시도해봤지만 귀에 상처만 나고 완전 짜증납니다..'],
#  [1, '아직 사용해보지 않았지만 믿고 5점 사용해 보고 잘 맞으면 재구매 할 예정이에요'],
#  [0, '형태 유지가 상당히 안되고 가방끈은 조여도 살짝틱 건들기만해도 바로 풀려버림'],
#  [1, '색상도 재질도 맘에 들어요! 역시 빠른 배송까지 좋습니다~'],
#  [1, '칼집을 다 내서 보내주셔서 구워 잘 먹었습니다'],
#  [0, '소소 ㅎ 누구나아는그코팅지입키다'],
#  [1, '절삭력 매우 만족.'],
#  [1, '그냥 대충 담아놓기만 해도 지저분한게 깔끔해지는 마법~ 라탄 너무 좋아요 엄청 견고합이다'],
#  [1, '장갑이 짱짱하고 패드도 좋아요. 장갑낀 상태에서 스마트폰 터치도 됩니다.'],
#  [1,
#   '아직 제대로 사용해보지는 않고 베개만 사용해봤어요 나름 시원한거 같습니당 근데 무겁기는 엄청무겁네요 더블 기준 8키로 라고 적혀있네용'],
#  [0, '듀론에 맞는다고 써있는데 안맞음'],
#  [0,
#   '볼트가 12mm라고만 써있어서 12x1.75텝으로 물건을 해놨는데 전혀틀린 2피치이상으로 나오죠? m12가 도데체 어디기준 규격인지'],
#  [1, '사용 하던 거치대가 부러져 구매했습니다.'],
#  [1, '내구성 좋고 드립할때 스무스하네요'],
#  [0, '누가 밟은것처럼 하나같이 다 더럽네요. 마시기도 전에 기분이 너무 별로에요.'],
#  [0,
#   '진짜 너무하네요ㅜ 욕실매트랑 주방매트 두개 구매했는데 털어도털어도 털이 계속나와요 그냥 털이 계속 뽑히는거 같네요ㅜ 마트에서 살껄ㅜ 한번 세탁해서 반품도 못하고 그냥 버리려구요'],
#  [1, '용기 디자인도 예쁘고!!믿고 사용해봅니다'],
#  [1, '재구매 찌거기가 걸러지는 것이 아주 좋아요'],
#  [0, '냄비가.너무 얇아서 잘 타는듯'],
#  [1, '저렴한 가격에 배송받으니 좋아요'],
#  [0,
#   '별한개도 아깝습니다. 이걸로 설치후 10일정도 자났는데 네비 멈춤현상이 지속적으로 발생 됩니다. SD카드의 문제 인줄 알았으나 본체에 SD카드 꼽으니 잘되네요. 교환 반품시기가 지나서 교환 환불은 어려울것 같아 돈 버린셈 치고 후기만 적습니다.'],
#  [1, '좋네요 ㄱㅈㄱㅅㄱ디ㅡㅂㆍㅇㄴㄱㅈ급ㄴㄱㅅㄱ다겄ㅊ극새ㅡㄱㄴㅂㅅㄱㄷㄱ내ㅡㅂㅅㄱㅈ긘ㅅㅇㅌㄹㅆㅇ드ㅜㄴㅅ딕ㅂㅅㅂ'],
#  [0, '상품정보제공고시에 제조국 국산이라서 샀는데 물건오니까 중국OEM이네요 수정해서 판매하셔야되는거아닌가요?'],
#  [1, '좋네요 알콤솜으로 소독하면 트러블도 안생기고 굳!'],
#  [1, '질이 좋습니다. 가격도 좋습니다.'],
#  [1, '재구매 저희 구입하고 친정엄마가 보시고 좋다고하셔서 구입해서 보내드렸어요 색상도 좋고 넘 잘쓰고 있습니다~^^'],
#  [1, '남자친구 사줬는데 신은게 훨씬 더 예뻐요'],
#  [0,
#   '이럴줄알앗으면안삿네요 옷도얇아서 지금입지고못하고 길이짧아진것도 분명제가시킬땐없던거같운데 이제보니 그런내용이잇내요 전 길게닞고싶어서산건데 배송조회자체도안되서 문의햇더니 원래안된다곸ㅋ그럼미리공지를해야지 보풀도잘일어나는재질이고 전별로네요'],
#  [0,
#   '중국에서 만들어서 그런지. .디테일이 많이 떨어집니다 (기스 짝짝이 도색벗겨짐 휘어짐 등등) 싼맛에 그럭저럭 쓰실분 사시면 됩니다~'],
#  [0, '고구마도 저랑은 안 맞네요 ㅠㅠ 포장은 정말 깔끔해요'],
#  [0, '너무 끈끈해서 밀려납니다. 아쉽네요. 제가 구매한거만 그런건지 궁금합니다. 쓸수가 없을정도입니다. 개선바랍니다.'],
#  [0, '배송이 너무 느려요..결국 급해서 철물점 쫒아갓네요..'],
#  [1, '디자인도좋고 경고하고 너무 좋네요~^^'],
#  [1, '배송빠르고 좋은데 휘어서 온게 잇네요 교환하기 귀찮아 그냥 조립햇더니 한쪽이 조금 빠지네요 그래도 튼튼하긴하네요'],
#  [1, '확실한 효과 기대할께요!! ㅎ'],
#  [1, '식기세척기 전용세제 찾다가 구매했어요. 설거지 잘되네요ㅎ만족합니당 재구매의사있어요'],
#  [1, '베송도 빠르고 상품도 좋아요^^'],
#  [1, '검은색 예쁨. 굿굿.신랑이 맘에 들어함'],
#  [0, '불량으로인한 판매자 마인드 불만족. 사과도없었어요.'],
#  [1, '항상 주문하는 제품으로 사이즈 좋고 무엇보다 손님들이 너무 맛있데요 .'],
#  [0,
#   '별루 사실 아이보리 사고싶엇는데 맘에 드는게 없어서 밝은쪽 쓰려고 투톤으로 고름. 근데 회색양면둘다 원래는 회색이었는데 많이 세탁해서 물빠진 희끗한 회색. 가격대비 가성비별루 반품귀찮아서 그냥 쓰다 바꿔야지 에휴'],
#  [0, '오프라인 매장보다 글루가 비싸요...'],
#  [1, '양도 되게 많고 좋은제품 저렴하게 구입할 수 잇어서 정말 좋았어요 착용감도 편하구 잪 쑬 수 있을거같아요'],
#  [1, '건식 다림 쓰고 있는데 커버를 씌우니 작업이 한결 수월하네요. 번창하세요.'],
#  [1, '배송은 조금 늦었지만 괜찮아요 좋습니다'],
#  [1, '좋아요!!! 맛도 괜찮고 다음에 또 시킬게요'],
#  [1, '배송은 빠릅니다. 제품도 가격대에 얼추 맞네요.. 면이 조금 까실까실 합니다. 프린팅은 조금 조잡해 보입니다. 수고하세요~'],
#  [0, '원단이 가재수건처럼 얇고 거칠고 들어올리면 다비친다. 반품신청하고 왕복택배비가 아까워서 그냥 쓰기로 했다'],
#  [1, '마음에 들어요. 레이어드용으로 좋은듯.'],
#  [0, '한진택배 배송이 너무 느려요'],
#  [1, '재구매 맛남의 광장보고 갓당근 김밥 만들었어요~ 갓피클 1kg 사서 만들어 먹고 또 구매했는데 정말 맛있네요~'],
#  [1, '그냥 적당한거같아요 좋지도않고..'],
#  [1, '너무 만족하며 사용하고 있습니다!'],
#  [0, '맛이 특별히진않아요 ㄱ ㅓㅁ은콩함유도 머 검은콩두유라 말하기 부끄러눌듯'],
#  [1, '사진과 다른점없이 정확합니다. 다만 플라스틱이다보니 정전기가 잘일어서 고양이털이 들러붙어 지저분해지는건 어쩔수가없네요.'],
#  [0, '핸들이 좀 헐렁거리네요'],
#  [1, '재구매 맛이기가먹홉니다 ㅎ'],
#  [0, '어어어ㅐ닌네에에에ㅔ엥'],
#  [0, '맛이.. 그닥 아기도 안좋아해요..'],
#  [1, '정알편안하네요ㅡㅋ진작살껄ㅠ'],
#  [0, '배송도 별로 색도 다르고'],
#  [0,
#   '재구매 엄마가 알로에 많이 좋아하셔서 여러번 주문해서 먹고 단골로 쿠폰도 받았답니다~ 이번엔 평소보다 대량주문했는데 엄마가 받아보시고 끝이 다 잘려오고 오래두지 못할것 같아 상품이 그전만큼 좋지 못하다고 하시네요ㅠ'],
#  [0, '바깥 페인팅이 안쪽까지 칠해져잇어요'],
#  [0, '몇일쓰면 너덜너덜해져요..'],
#  [1, '배송빠르고 향도 좋고 케이스도 고급스러워요'],
#  [1, '안찢어져요'],
#  [0, '아주좋아요 싸고 맛있어요'],
#  [1, '배송이 완전 번개배송이네여 ㅋㅋㅋ 확실히 방이 밝아보여요'],
#  [1, '처음에 연결되지않아 몇 번 시도하다가 결국 수동으로 입력했어요~ 그리고 간혹 LTE 가 끊기는 증상이 있어서 별 4개입니다~'],
#  [0, 'ㅠㅠ 약간 후회가 됩니다..'],
#  [1, '매일매일 잘 먹고 있습니다. 밥이랑 야채랑 먹으니 든든해요 건강해지는 느낌이예용'],
#  [1, '디자인, 사이즈, 색상 등 모두 보이는 그대로입니다. 다리도 견고한것 같습니다.'],
#  [1, '혹시나하고 주문해봤는데 걱정할필요가 없었어요 한줄기 맛본다는것이 밥한그릇 뚝딱~ 정말 맛나요 ~~ 감사히 먹겠습니다'],
#  [1, '재구매 항상 잘 먹고 잇습니다 고마워용'],
#  [0, '급해서 쓰기는 했지만 정말 거지같네요 왜 엉뚱한 회색을 보냈는지요?'],
#  [1, '10일만에 배송되어 너무 오래 기다려 별 1개 뺐어요. 유효기간도 2023년까지라 좋고 포장도 꼼꼼하게 잘 되어 왔네요~'],
#  [0, '생각보다는 괜찮은거 같은데 약간 뻑뻑하네요'],
#  [0, '아무도움 안되요. 쓰고 바로 쓰레기통으로'],
#  [1, '아주 좋습니자'],
#  [0, '집에서 입으려고 샀는데 색깔은 사진과 달라서 교환할까 하다 그냥 입으려구요.'],
#  [1, '안경 크기도 딱 원했던 만큼이고 가볍고 좋습니다👍'],
#  [1, '가성비최고입니다 색도예뻐요.'],
#  [1, '만족해요 싸게 잘 산듯'],
#  [1, '기존 써왔던 실크모보다 벨벳모가 훨씬 더 부들부들해서 진짜 속눈썹같고 가볍고 좋아요~~~^^'],
#  [0, '이건아님 다죽어서 오고 생물삿는데 죽어서 먹기 찝찝해요 어찌한마리도 안살아 잇을수가ㅠㅠ 진짜후기보고삿는데 의심가네요'],
#  [0, '일주일 사용해봤는데... 더 쓰고 볼게요'],
#  [0, '유통기한이 제조일로부터 18개월이라는데 제조일은 도대체 어디다 쓰신건가요?'],
#  [1, 'ㄱㄴㄷㅡㆍ ㄴㅅㅂ 기 ㆍㅡㄷㅈㅅㅈㄴㄷ긧ㄴㅅㅇㅂ ㅣㄴㅅ ㅈㄷㅡㆍㄴㅅㄱㅈㄱㅎㅋㅅㅈㄱㄷ븑 ㅂㅈㄱㄹ'],
#  [1, '배송이 예상한 날짜에 잘 도착했어요.'],
#  [0, '생각보다 별루입니다'],
#  [1, '감삿합니다'],
#  [0, '버렸어요 씻어서 살짝 데쳤는데 너무짭니다'],
#  [0, '먼지를 빨아들이는 힘이 거의 없다시피함'],
#  [1, '만족합니다 먼지가 잘 안난다는 상품평들 보고 구매했고, 기존에 사용하던 휴지보다 먼지가 덜 나는것같아서 좋아요'],
#  [1, '잘도착 했어요 배송 빠르게 잘 도착 했어요~ 장농에 있던게 고장나서 새로 구매 했네요 배송 잘 받어서 교체했어요'],
#  [1, '너무 잘샀다 생각하네요 잘쓸게요~'],
#  [1, '오래된 화장실이 싹 정리 돼요. 부착간편하고 튼튼합니다.'],
#  [1, '젖병은 어쩔수 없네요~~ 일본불매라고 해도... 젖병은 더블하트네요 ㅠㅠ'],
#  [0, '너무줄이 얇다. . 상당히별로다'],
#  [0, '집에벌래가하나도업나봐요.7일동안깨끗하네요 ㅋㅋ'],
#  [0,
#   '리뷰에 3.1키로도 가볍다는 것을 봐서 여잔데 힘쎈편이라 맘놓고 주문했다가 너무 무거워서 허리에 크게 멍들었어요 그래도 멍없어진담에 다시하니깐 좀 적응된거같긴한데 또 이거 색깔이 살색에 초록색이라 좀 징그러워요 ㅠ 글고 엄청 큽니다'],
#  [1, '친절함에 감사드립니다 ^^'],
#  [1, '오프라인대비 가격이 저렴하고 포장상태 배숭상태 다만족합니다 물론 크록스 정품이고 반절이상싸네요'],
#  [0,
#   '일주일에 한번씩 두번사용했는데 어이없게 끊어지는...타이트하게 매서 잡아당기는것도아니고 무거운거 계속들고있었던것도아니고...완전 몇천원 버린기분입니다'],
#  [1,
#   '가격대비 제품의 질과 디자인이 너무 이뻐요^^ 지인분들에게 적극 추천해주고 싶은 제품이네요 색깔도 원하는 색이 아니면 어쩌지하고 걱정했는데 받는 순간 괜한 걱정했다는 생각을했네요~'],
#  [0, '배송이상하게해줌'],
#  [0, '마음에 들어요~!'],
#  [0, '제품은 항상쓰는 제품이라 구매했는데...'],
#  [1, '왤케맛있어요? 장난함?'],
#  [1, '달지않아서너무좋아요.'],
#  [1, '레드컬러 너무 이뻐요~~~ 잘 산거같아요'],
#  [0, '사이즈가 많이 작고 부드럽지않고 까끌합니다'],
#  [1, '펄이크고 화려한 스타일의 하이라이터네요 배송은 주문다음날 도착햇어요'],
#  [1, '깔끔합니다~! 우윳빛이네요'],
#  [1, '분사력도 좋고 세척이 편리합니다'],
#  [1, '배송이 엄청 빨라요 내부도 엄청 넓고 좋아요'],
#  [1, '항상 시켜먹는 믿고 먹는 마이쉐프입니다 편하고 맛있고 푸짐하고 항상 좋아요^^'],
#  [1,
#   '약간 크게 제작이 되었는데 책상이 아니고 서랍장 위에 덮으려고 구매한거라서 약간 큰 게 더 좋은 거 같아요 그리고 사용하다보면 조금 수축된다고 해서 딱 맞는것보다 나은 듯 합니다 요거 덮어놓으니 깨끗하고 깔끔해서 좋아요'],
#  [1, '찍찍이가 양쪽에 있어서 불편하다는 후기봤는데 전 괜찮던데요. 재질이 천이 아니라서 물 뭍으면 바로 말라서 좋을것같아요'],
#  [0, '커케누녀뉴니야루메쟈융'],
#  [1, '아주아주만족해요~~~운동 퐈이팅하게 하고 주변에 많이 알릴께요~!!ㅋㅋ'],
#  [0, '핸드폰 메모리용으로 구매했는데 만족해요'],
#  [0, '진짜 지속이고 커버든 다별로 몇시간도 안가고 너무 그냥 얼굴전체가뜸 기초탄탄히해도 이건정말 너무별로 홈쇼핑에서ㅓ 안사깅 다행'],
#  [0, '이름넣는분들많은데.... 나도그랬는데....쪽팔려서 못하겠음'],
#  [1, '배송두빠르구조아여'],
#  [1, '빠른 배송. 데스크랑 일체형. (출시 알려 주셨으면 더 좋았을 것을.)'],
#  [0, '어쟈저어유더자다더누루주'],
#  [1, '쓰던게 낡아서 구매했네요,^^'],
#  [1, '5개 샀는데 다 잘됐어유^^'],
#  [1, '잘 사용하고있네요~. 근데, 어깨끈이 쉽게 늘어나서 벌써 쭈글쭈글해요. ㅡㅡ'],
#  [1, '변하지않는 꾀돌이👍'],
#  [1, '재구매 좋아요.아이가 아주 좋아해요♡'],
#  [0, '가격대비 좀 부족한게 많은듯'],
#  [1, '매우 신선 열어놓으니까 점점 활발해짐. 황장이 가득 수율도 80퍼 이상, 신선해서 살결이 그대로 느껴짐 바로 또 먹고 싶음'],
#  [1, '현관문옆에 홈바식으로 사용하는데 이뻐요 한가지 단점은 아래 수납할때 기둥때문에 박스같은게 못들어가요.. ㅜ'],
#  [0, '안좋아요 신생아인데 잘안먹으려고 하네요ㅜ너무 조금씩나와서 빨기힘든가봐요 그린맘쓰다가 바꿔봤는데 실패ㅜ'],
#  [0,
#   '재구매 이 곰팡이냄새 나는 상자에 담아주는 왜 그런건가요? 종이지관을 담아주는데 곰팡이 핀 상자에 담아주면 찝찝해서 어떻게 사용합니까? 너무하는거 아닙니까?'],
#  [0, '물에 잘 풀어지는 만큼 질기지 못하네요'],
#  [1, '빠르게 잘받았어요 색깔도 이쁘고 좋네요'],
#  [0,
#   '계속 무선충전을 중지한다고 오류가떠요 ㅠ 상성어뎁터를 써서 그런거같은데.. 어뎁터우선 다시구매해보고..안되면 반품요청하려고합니다..'],
#  [1,
#   '작은 사이즈이지만 시원하고 좋아요. 설치 엄청 빨리 잡아주셨어요. 설치비가 물건값의 거의 2배인게 좀 속상하지만 넘 깔끔히 작업 해 주시고 친절히 대해주셨어요. 추천!'],
#  [1, '재구매 좋아요 역시 휴지 질도 넘나 좋아요!'],
#  [1, '공항에서 잘 수령하여 잘쓰고 있습니다'],
#  [1, '뽁뽁이 기사님이 엉뚱한데 두고 갔지만 하루만에 다시 와서 감사'],
#  [1, '밀키스맛이랑 비슷한 것 같아요~'],
#  [1, '이쁘네요 이뻐요 받자마자 확인해봤어요. 여자친구 생일이 1주일 남았는데 제 눈엔 엄청 이쁘네요. .'],
#  [0, '지속력 발림성 모두 짧고 색상은 화면보다 훨 어둡고 칙칙 합니다'],
#  [0, '사이즈가 좀 큰편이고 챙부분 마감처리와 모자옆면 마감처리가 좀 엉성하네요 가격대비 그저 그렇습니다...'],
#  [0, '리커버리는 개뿔... 걍 거품 스폰지같네요... 절대 사지 않아도 됨'],
#  [1, '싸게잘이용했어요 좋네요 ㅋㅋㅋ'],
#  [1, '잘 받았습니다 만두가 생각보다 커서 놀랐네요'],
#  [0, '잘받았습니다요오오오'],
#  [0, '태어나서 처음으로 해본건데~ 피지가 하나도 안나오네요?'],
#  [0, '몇번째구매,, 이런경우는 없었는데,, 봉투 안에 물이 새네요,, 마무리가 제대로 안된듯,,'],
#  [0, '저하고는 안맞는듯요 다른분선물줬네요'],
#  [0, '사고 얼마 안있으니 로뵷 변신 제품이...'],
#  [1, '건전지 안써도 되고 좋아요'],
#  [0, '돈아까움 설치하고 양면테잎 바로 떨어져서같이보내준거 설치 그래도 반대쪽은 또 떨어짐ㅠ 사실 돈 진심 아까움'],
#  [1, '포장도 잘되서 잘 왓네요!!'],
#  [1,
#   '고급스럽게 예쁘고 가벼워요. 코니 아기띠에 해봤는데 코니는 걸곳이 없어서 흘러내리긴하는데 할만해요~ 혼자서 착용하기 쫌 불편하고 천이 얇아서 찢기진 않을까 걱정되네요~그래도 아기 보낭으로도 쓸 수 있고 예뻐서 만족합니다~'],
#  [1, '잘 사용하고 있오용 천도 부드러워서 안경도 깨끗히 잘 닦이고 좋내용 잘. 애용하고 있어용'],
#  [0, '처음으로 입었는데도 보풀이 넘 많이 생겨요ㅜ'],
#  [1, '깔끔하고 잘입고있어요'],
#  [1, '저렴하게 구매했어요. 전에 철물점에서 비싸게 주고 샀었는데 훨씬 저렴하네요.'],
#  [0, '마카다미아는 처음 시켜봤는데 다른 곳 상품을 안 먹어봐서 정확히는 모르겠지만 맛이 썩 좋지는 않네요. 신선하지가 않아요.'],
#  [0, '사이즈가 안맞아서 붙일수가 럾었음'],
#  [0,
#   '두달 썼는데 그냥 타이어가 좀더 진해질뿐 반짝반짝한 광은 없네요 관리 잘 된 차 느낌 받으려면 비추입니다ㅠ 다 안 쓰고 다른거로 넘어갑니다'],
#  [1, '이뻐요! 주문하루만에 배송... 빠르네요~~ 살짝큰감이 있긴한데 맘에들어요~ 다른스타일도 구매하고싶ㅇㆍㄱ요'],
#  [1, '아이들 선물 넣어줬는데 예뻐요'],
#  [0, '넘 작아요ㅡ 불편해서 안 입어요 ㅠ'],
#  [1, '재구매 항상 여기 쇼핑몰 이용합니다. 흑 배송비가 흑흑. . 슬퍼요. . 배송비만아니라면 최고로저렴한곳. .'],
#  [1, '계속 사용하던 제품입니다^^'],
#  [0,
#   '무독성 맞나요? 일단 더러운상태여서 닦아도 기스가 많고, 냄새가 너무너무 심함 개봉해놓구 3일 뒀다가 붙이고 나서 방에서 냄새 3일 감 하.. 그리고 효과 없음. 잘 생각하고 구매 하세요'],
#  [1, '넉넉하니 크내요 이번캠핑에 잘 쓸수 있을꺼 같아요'],
#  [0, '설치하기 조금 힘들었어요 빡빡하고ㅜㅜ'],
#  [0, '가격만큼만 하는것 같네요.'],
#  [0,
#   '배송도 그저 그렇고 색상이 품절됐음 품절 표시를 해 놔야 하는데 여긴 그런것도 없고 전화로 품절 됐다고 ..연락와서 색상 바꾸고 ..색상을 바꿨는데 그것도 춤절됐다고 연락 오고 .일처리가 별로 였어요 ..여기서 이제 구매 하고 싶은 마음이 없음 ..'],
#  [0, '사지마세요ㅜ저렴한이유가'],
#  [1, '처음엔 향이 좀 쎘는데 잠깐 틀어놓으니까 괜찮아졌어요!! 샤워하고나면 욕실에 좋은 향으로 가득차서 기분이 좋아지네용~~~'],
#  [0, '재구매 너무 큰것만 왔어요. 금방 썩었어요.'],
#  [0, '너무 별로예요.절대 구매하지마세요.몇번을 배달됐냐고 전화를 했는지..몇천원 더 싼데서 하려다가 열받아서 ..기본이 안된곳입니다'],
#  [1, '제품이 좋음'],
#  [1, '재구매 항상쓰던건데 이번엔 사이즈 주문실수'],
#  [0, '하나만 살 걸.. 두개 동시에 산 거 후회중. 서랍에서 썩고 있어요'],
#  [0, '잘못 구매했어요. .'],
#  [1, '잘 맞고 잘 닦입니다!!!! 좋아요!'],
#  [1, '아몬드함량이 높아좋아요. 싼가격에 많이 살수있어 좋습니다.'],
#  [0, '그지같음 잔머리굴리지말길'],
#  [1, '재구매 빠른배송. 냥이들이 잘먹어요'],
#  [0, '너무 덕지덕지 발리는 느낌이에요.'],
#  [0,
#   '에어프라이어에 구워 먹을려고 샀는데단맛도 없고 텁텁한게 맛없네요. 여지껏 사먹은 고구마중 제일 맛없어요. 다신 안사먹고 싶네요. 어떻게 처리해야할지ㅜㅜ'],
#  [1, '재구매 이에 달라붙지않고 넘 달지도 않고 맛있어요. 사탕 초콜릿보다 훨씬 좋아요'],
#  [0, '열어보니 원목들이 부분부분 파손되있고 조립하고 세워놓으니 흔들흔들... 싸게쓰니까 써요'],
#  [0, '500루멘 아래로는 실사용이 어렵습니다. 너무 어두워요... 성능 대비 가격이 비싼 느낌입니다'],
#  [0, '핸드폰으로 바로 영상을 확인할수있는제품이아닙니다 무료장착이지만 탈거비는 내야합니다'],
#  [1,
#   '넘 좋아 사람들이 아직도 데오드란트를 모르다니 ㅠㅠ 남자들 냄새 ㅈㄴ 쩔어 제발좀 써라 몸에서 하수구 냄새난다구 ㅠ 왜안쓰는지 ㅠㅠ'],
#  [1, '이 가격에 이 퀄리티면 사야한다고 생각합니다'],
#  [0, '저렴한티가나요ㅠ_ㅜ'],
#  [0,
#   '어릴때먹어본기억이있어서 한번사봤어요. 제가 먹어봤던 그맛이 맞는건진 모르겠는데..? 신선한건좋은데 새콤달콤한맛이있는거같으면서 맹맛같기도하고 약간 떫은거같아요.'],
#  [1, '블랙은 딸이 가져가 버렸네요 ^^ 블랙은 어디에나 다 잘어울려서 활용도가 높아요'],
#  [0, '.. .. ㅅ.ㅈ느ㄴ돈 날렸어요'],
#  [1, '여기진짜맛있어요ㅜㅠ'],
#  [1, '배송 빠릅니다 지퍼 잘 잠깁니다 많이 파세요'],
#  [1, '분유랑 같이 주문해서 받았어요. 깔끔하게 왔어요.'],
#  [1, '치약맛이 조금다르긴한데 상쾌하고 좋아요 재구매의사있어요'],
#  [0, '‘ 발송완료로 잡아놓고 늦게보내네요 취소할까봐그런지는몰라도 기분나쁘네요 다음엔 안시킬거같아요 여기선'],
#  [1, '빠른 배송 감사합니다! fcpoint@naver.com으로 패치 보내주세요!!'],
#  [0, '좀 구겨져서 왔는데 귀찮아서 그냥 써요'],
#  [0, '오리온 베이지 설치했습니다, 색상이 미색이 아니라 엘로우에 가깝습니다.'],
#  [1,
#   '주문하고 그다음날 배송 받았어요 프리퀀시 다 해서 받고 싶은데 갈때마다 없어서 그냥 인터넷 구매 했네요ㅜ 받고 보니 역시 이뻐용'],
#  [0, '제품에 하자는 없으나...기대가 너무 컸나봐요... 별로 맛은 없네요....'],
#  [1, '수평이 잘 안맞긴하는데 예쁘긴합다!'],
#  [0, '가격대비 별로에요!!'],
#  [1, '순정보다 확실히 밝아요 시인성 좋은거 같아요 포장도 꼼꼼이 잘해서 왔구요 배송도 빨랐어요'],
#  [0, '배송빠름 세개중 하나는 새서 양이 적음^^'],
#  [0, '상품포장이 바뀐건가요?'],
#  [0, '먼지가 잘 안 붙을 것 같은 재질인데 마감이 별로라 어떻게끼워도 삐뚤합니다. 싼맛에 하겠지만 다음엔 구매하지 않을 것 같아요'],
#  [1, '신선하고 너무맛있어요!^^'],
#  [1, '좋습니다! 킨즈! 역시나 만족스러운 제품입니다.'],
#  [0,
#   '세번째 액정 자가수리한 사람입니다. 살살 다루기도하고 영상보고 따라할정도로 총작업시간 1시간가량 걸렸습니다. 다른곳 이상 하나도 없습니다 다만 홈버튼이 전혀 반응하지않고있습니다 커넥터의 문제인지 제문제인지 모르겠으나 세번째만에 처음 발생한 일입니다.'],
#  [0, '냄새가 많이 나요ㅜㅜ'],
#  [0, '바닥부분은 플라스틱/중간봉은 나사가들어갈자리에 구멍이안뚫려있음/ 다른중간봉은 휘어있음 /전체적으로 가벼움 좋은나무는 아님/싼맛'],
#  [1, '같은것 하나더샀습니다. 맘에들어요~'],
#  [1, '역시 배송짱입니다^^ 잘쓰겠습니다.'],
#  [0, '긁힌거 왔어요'],
#  [0, '배송빨랐는데포장상태별루..'],
#  [0, '12월 25일에 붙였는데 1월 4일인 오늘 벌써 깨지고 두번째 붙였네요 핸드폰 떨어트린적도 없는데 하하'],
#  [1, '좋아요^^ 평소사이즈보다 한치수큰걸로 구입하니까 딱맞네요'],
#  [1, '좋았어요~~~~~~'],
#  [1, '맘에 듭니다 잘쓰도록 할게요%!!'],
#  [0, '너무 매트해요....'],
#  [0, '맛이 너무 별로 였어요. 가격이 저렴한 탓도 있겠지만 저는 버렸어요. ㅠㅠ'],
#  [1, '예전부터먹던거였는데 예전에 비해 많이 딱딱한게섞여있네여'],
#  [0,
#   '쉽게 먹기편한거 말고 맛도 양도 질도 다 별로에요 게장을 먹는다는 느낌보다 양념장으로만 느껴지네요 배송 엉망이었고, 이거야 뭐 실수가 있을 수 있으니.. 근데 상품은 궁금증에 한번은 먹을까몰라도 두번은 안먹을래요'],
#  [1, '숨쉬기가 편하네요 사이즈는 큽니다'],
#  [0, '잘 갈라지고 접착력이 좋지않음'],
#  [0,
#   '누가 반품한 물건을 그대로 보내신 것 같아요 택배상자도 무슨 아이크림 상자에 보내왔고 다른 집 주소로 적힌 송장번호도 그대로 겹쳐 붙여져 왔네요 대충 물건 확인만 했는지 뽁뽁이에 테이프 덕지덕지 붙인 것도 그대로고 정말 기분나빠요'],
#  [1, '배송 잘 받았습니다. 하루만에 배송되었네요'],
#  [0, '뚱뚱해서그러지 배가말려요'],
#  [1, '좋은 품질과 빠른 배송으로 잘 사용할 수 있을 것 같아요'],
#  [1,
#   '산소포장으로 꼼꼼히 포장되어 받았구요 배송받았을 때 아주 싱싱하게 살아있었어요 친정엄마 대신 구매해서 시댁으로 보내드렸는데 좋은걸로 보내주셔서 시댁에서 좋아하셨네요 살짝 데쳐먹기도 하고 생으로도 먹고 했는데 맛있었습니당'],
#  [0, '지문이계속남는아쉬움이있었습니다.'],
#  [0, '빨강색 치마랑같이 코디하려고 빨강때문에 산건데 빨강이 없네요 ...'],
#  [1, '이전에 먹고 만족해서 재구매합니다'],
#  [1, '선물용으로 구입했는데 만조합니다/.'],
#  [1, '살짝 끈적거리는?느낌이지만 좋아요'],
#  [0, '화이트 색상이 아니에요'],
#  [1, '양이 대박입니다. 울 꼬북이도 좋아하는걋 같구요'],
#  [0, '사이즈 스몰샀는데 미듐살걸 그랬어요 ㅠㅠ'],
#  [1,
#   '빈티지 이너백이예요 박음질도 좋고 소재도 괜찮은데 조금 두꺼워요 가로폭이 살짝 커서 가방에 넣으니 우는 듯하지만 각이 잘잡혀서 좋네요'],
#  [0,
#   'Mini 5pin 2개구매했는데 1개는 micro5pin왔네요 그리고 제꺼 외장하드는 호환이안돼요 불은 들어오는 실행안돼요 그래서 지인한테 mini 5pin구해서 연결하니잘됨 이건참 너무하네 반품하려다 걍 휴지통에버림'],
#  [0, '털빠짐이 심하네요 ...'],
#  [0,
#   '싼거라 그런지 금방 보풀일어나고 안좋아요 매일입은것도 아니고 가끔 한번씩 입었는데도 그러네요 겨울만 입고 버리려고 산건데 이건 한달도 안가요..ㅜ'],
#  [0, '생각보다 거칠고 자극이 잇는거 같아요 피부에 ..'],
#  [0, '무용지물...1000 언도 아깝다는.'],
#  [1, '눈 마사지후 시원한 느낌이 들어 피로가 풀리는 것 같습니다.'],
#  [1, '배송은 좀 걸렸지만 제품 완전 맘에들어요'],
#  [1, '기대 안했는데 좋으네요 ~'],
#  [1, '완전 대만족 불량 없이 잘 도착했습니다! 감사합니다 번창하세요!'],
#  [0,
#   '사자마자 캠핑지 가서..동봉되어있는 실팩으로 4방을 고정하는데... 한쪽 팩고정 밴드가 투두둑 하면서 풀리더군요...황당했습니다. 그래서 결국 3군데만 고정해 사용햇습니다.'],
#  [0, '정말 나사 조립 부분이 견고하지 않으나 나무 자체는 꽤 무겁움 의자 다리 부분 가시에 다 칠 수 있음'],
#  [1, '재구매 빠른배송감사합니다. 잘받았어요!'],
#  [0, '광택만 내주고 폴리싱은 전혀 안되는거 같네요'],
#  [1, '진짜 편하고 좋아요 완전 잘입고있어요 ㅎㅎ'],
#  [0,
#   '울트라에 정전식 펜 좀 쓰려고 했는데 손가락 보다도 못하네요. 근래 최악 픽. 차라리 팁을 좀 날렵한 스폰지 계열이 훨 좋을 듯 하네요. 기존 나오는 둥그런거 다양화 해서. 펜은 쓸만 해요.'],
#  [1, '적당히 쓰기좋아요 가격대비 만족합니다'],
#  [0, '4-7세용으로 되어있는데 5세아이 팔에 짧아요'],
#  [1, '기존에쓰는것보다 도톰하고 한장씩 뽑혀나와서 좋아요'],
#  [1, '생각보다작아요근데귀엽네요ㅎㅎ'],
#  [1, '몇년째 항상 주문해서 먹는김이예요 애들도 엄청 좋아해요^^'],
#  [1,
#   '집분위기에도 잘어울리고 좋은데 무풍에어컨 3구멍짜리는 195인가 그게 맞는데 캐리어에어컨도 그거 사라서 삿는데 안맞아요 ㅠㅠ 그래도 잘어울려요 조희가 잘못산건진 모르겠지만 그냥 잘 쓰겠습니당 집이환해져영'],
#  [0, '수저통밑이 물빠지는곳이없는형태 생각보다 좁음 몇개안들어감 실용성보단 인테리어'],
#  [1, '생각보다 좀 얇긴한데 부드럽고 좋아요!'],
#  [1, '새우철이라서 집에서 소금구이 해먹고 싶어서 구입하게 되었는데 너무좋고 편하네요^^ 정말 강추해요~~'],
#  [0, '알이 너무 작아 아쉽네요.'],
#  [0, '칠이 다 벗겨지네요..휴'],
#  [0, '한글설명서를 첨부해주시면 좋을거같네요'],
#  [0, '프리사이즈 절대 아닙니다 55반,66사이즈이상 절대 못신어요'],
#  [0,
#   '맛은 아직 안봐서 모르겟는데 유통기한이 너무 임박이에요;; 이제 곧 4월인데 6월12일까지 다 먹어야합니다 제조한지 9개월된 상품을 보내는건 너무하신거 아닌지..? 맛있으면 재구매할때 정말 고민되겠어요'],
#  [0, '냄새나고 표면 거칠거칠합니다'],
#  [1, '처음 사봤는데 맛있습니다'],
#  [1, '바닐라 냄새가 진동을 해서 일단 좋고 길이 조절로 줄 자를때 조금 조심하셔야 됩니다. 아주 만족합니다!'],
#  [1, '너무 예뻐요~ 사이즈도 크고 로즈핑크색상도 맘에 들어요~'],
#  [0, '아직먹어보지못했어요저렴히샀어요맛이.기대되네요'],
#  [0, '미세하게 효과가 있는거 같긴 한데 붙였을때 생각보다 티가 많이 나고 뗄때 좀 아파요..'],
#  [1, '역시아주아주좋습니다요'],
#  [0,
#   '물온도가 너무 낮습니다.반정도 마시다 보면 벌써 미지근한 상태가 되네요 커피는 뜨거운 맛으로 마시는데 전자렌지에 다시 돌려 마실수도 없구 반품하고 싶은 마음 간절합니다.'],
#  [0, '배송일정 최악이네요'],
#  [0, '우유 다 쎄요. 우유 다 흘러서 애가 들고 마실수가 없어요'],
#  [0, '색상이 흰색이었더라면 더 좋을 듯하고, 크기는 작은데 연결부분이 헐겁지 않다면 100% 만족입니다.'],
#  [0, '재구매 항상 잘왔는데 이번에는 위에가 찢겨서왔네요'],
#  [1,
#   '좋아요 냄새도 안나고 제품자체는 좋은데 삐뚤지 않게 집에서 깔끔히 시공하는건 거의 불가능하네요.. 시공어려운것과 이미 제단되서 올때부터 삐뚠부분이 잇는건 아쉬운점이에요'],
#  [1, '이유식할려구샀어요색깔이참예쁘네요'],
#  [1, '이거있으면 이제외출할때 아이쪽쪽이깨끗한가 안깨뜻한가 걱정안해서 좋아요~ 사이즈두딱좋고 귀여워서 맘에들어요~'],
#  [1, '배송이 빠르고 무선이라 정말 좋아요.'],
#  [1, '구성이 좋아요^^ 잘볼게요~'],
#  [1, '물이 정말 쓰으윽 말라요 좋아요!'],
#  [0, '재구매 너무커서 맛이 그냥 그랬어요 당근은 작은게 맛난데'],
#  [0, '재구매 다좋은데 배송에 다소 문제가있어요!'],
#  [1, '이쁘네여으ᄀᆞㅅ'],
#  [1, '생각보다 맛있고 저는 오히려 시중 아이스크림보다 부드럽고 더 맛있다고 느꼈어요!!'],
#  [0,
#   'Aㅏ....... 처음에 후기 좋게 썼는데 일주일 만에 기스 작렬에 뒤에 다 벗겨지고 ㅠㅠㅠ 한달도 못쓰고 버렸어요^^....... 돈 버림...'],
#  [1, '그라시아 원래 좋아해서~마음에 들어요'],
#  [1, '잘받았습니다 생으로 먹어도 맛도 좋고 당도도 좋네요'],
#  [0, '일회적으로 신게되는 것 같네요~'],
#  [0,
#   '밑위가 사진보다 더 짧아서 정리하고 입으셔야해요 다리 넣는 구멍이 작고 신축성이 없어서 피안통할듯 임신하면 계속 불어날텐데 부적합한것 같아요'],
#  [0, 'ㅜㅜ장착하긴했는데 ㅜㅜㅜ'],
#  [0, '가격이 저렴한 만큼만 합니다'],
#  [1,
#   '케이스가 고급지네요^^ 뚜껑열때 뽝!!힘듬ㅎㅎ 까망&골드~빤짝빤짝~블링하네요.. 처음 붙일때 에센스가 많아서 흘러내리지만..잘붙잡고 누어서 자리잡으면 아주 쫙~하고 붙어있네요^^부지런히 사용해보렵니다♥ 샘플도 주셔서 감사하네요^^'],
#  [0, '고무냄새가 많이나구 아가들이 전혀 관심를 절대 안갖음'],
#  [0, '디자인은 이쁘지만 차량용으로는 단점이 많아요 운전하는데 방해요소가 됩니다.'],
#  [0, '싸이즌 잘 맞는데..불편..원단은 좋음'],
#  [1, '색깔이 마음에 들어요!'],
#  [1,
#   '가습기도 필요하고 무드등도 있으면 좋겠다고 생각했는데 둘 다 쓸 수 있어서 너무 좋아요. 귀엽고 간편하고 조용해요. 유에스비연결 방식이 불편할 것 같았는데 역시 좀 불편해요. 그치만 예상했던 것이니 ㅇㅋ!'],
#  [0, '잘 나오네요 쭉쭉 나올 줄 알았더니'],
#  [0,
#   '재구매 일딴 잘 떨어집니다. 그리고 내구력이 약하다보니깐 운정하고 어느순간 보시면 도어가드 몰딩이 떨어져 있는걸 확인 할수 있을꺼에요. 크롬이라서 이쁘긴 하지만 굴곡에서는 끼어지지도 않고 구부러진다는.. 한달 그냥 쓰다가 버리고 다른 재품으로 샀어요.'],
#  [0, '좋다는 분들이 많ㅇ던데 제가 써보니 무릎뼈 부분이 조금 불편해요'],
#  [0,
#   '확실히 화면발... 실물 퀠리티는 없다.. 생각하시는게 좋을듯합니다 그냥 쓰시기엔 나쁘지 않을듯한데 제 생각과는 너무 상반될뿐이네요 방석은 필수요~'],
#  [1, '[스마트스토어] 작은 친구들 토끼,기니피그,친칠라 복층형 하우스(A-RB80)네이비ㅇㅋ'],
#  [1, '재구매 빠른배송감사합니다 너무 편해요'],
#  [0, '상태가 안좋지만 판매자님께서 매실청 담는데는 문제없다하여 믿고 일단 담습니다~ ㅠㅠ 불안불안하지만요'],
#  [0, '물맛이 가족들이 이상하다하네요'],
#  [1, '휴가때 잘 썼어요!'],
#  [0, '두께가 넘 얇아요. 그래도 아이들이 잘 갖고 노네요'],
#  [1, '재구매 몇번째 재구매인지 배송도 빠르고 이 더위에 꽁꽁얼려서 왔어여 이번엔 다이어트 성공하고싶어요'],
#  [1, '재구매 매달 구입해서 사무실서 마시는데 가격이 부담없고 맛도 좋아요'],
#  [1, '잘먹고잇어요 많이파세요'],
#  [1,
#   '보습력 정말 칭찬해요 피부가 악건성이라 요즘 긁느라 공부도 못하고 잠도 못자고 난리였는데 보습력 좋다는 후기보고 구매했습니다 샤워 후 바르고 자고 일어났는데도 촉촉했어요 앞으로 꾸준히 바르면 효과 제대로 볼듯해요 기대됩니다~~'],
#  [0,
#   '앞바퀴 밸런스가 맞지않아 문의했는데 답도없고... 결국 자전거 본사로 연걀했더니 조립탓만하네요.(조립 별거없고 남편이 이쪽 경험이 있는데두) 왈가왈부하기 싫어서 자전거 as받으러 갔고 그거 튜닝해주면서 4만원 들었네요 조립으로 구매하세요'],
#  [1, '파우더 프리라서 믿고 샀어요.. 대부분 품절이라 간신히 산 보람이 있길요~'],
#  [0, '고기가 질기고 핏물이 넘많이 빠져서왔어요. 보냉제가 적게 들었네요'],
#  [0,
#   '일주일간 잘썼는데 자꾸사진처럼 펜촉이 빠지고 글쓰는건 좀되는데 짧은터치가 거의 안먹혀요 그나마 꾸욱눌러야가끔되는정도...?ㅠ 그래서 본목적인 필기는 거의못하고있어요ㅠㅠㅠ'],
#  [1, '좋아요 주변에서 추천 많이 받아서 한번 사봤어요 다른데보다 저렴하네요!! 저도 효과봤으면 좋겠네욤'],
#  [0,
#   '착용감은 편한데 단독으로는 티가 나서 사용하기 그러네요. 두꺼운 옷은 모르겠는데, 얇은 옷은 티 나요. 특히 밝은 색 옷은. . 자연조명에서는 티나서 움츠러들게 되네요. 여름 옷에 입으려고 샀는데 별로예요.'],
#  [0,
#   '불만입니다. 귀찮고 포장을 찢어서 반품은 않겠지만 효과는 없네요. 반품하고 싶은데.... 포장박스를 없애서 반품도 못하고....'],
#  [0, '일단 배송이 느립니다 사용한 후에 다시 남길게요'],
#  [0, '가격대비 퀄리티는 좀 떯어지는듯 하네요'],
#  [0,
#   '업체가 마음에 안드네요. 이불 샀는데 사진과 이미지달라도 너무달라 속았어요.거기다 반품비까지 내라내요.몇천원 내면 그만이지만 눈이 있다면 사진과 실제와 비교해보시기를 바랄께요'],
#  [0, '배송이 너무 느리네요 테이블에 키보스 서랍 만들었네요'],
#  [0, '굉장히 작습니다..전체 크기가 3센티..너무 작아요..'],
#  [1, '꿀고구마라 달달하니 맛나네요~ 에어프라이어에 구워서 아이들 간식으로 챙겨줬어요~ 다음에도 재구매 의사 있습니다^^'],
#  [1, '빠르고좋네요.다음에도기회가된다면 구매하고싶네요'],
#  [0, '흠 ... 보정이 안되는거 같아요 한사이즈 작은걸 시킬걸 그랬나봐요 ㅠㅠ 걍 스판 나시정도?'],
#  [0, '플라스틱에서 고약한 냄새가 진동합니다 모양은 좋네요'],
#  [1, '좋아요 아주 만족합니다 예전에 자격증 취득할때 구입해서 잘사용했는대 다시 또 공부를 하게 되어 구입합니다'],
#  [1, '깔끔 1-2인 가구에 딱일듯한 아이템이예요^^ 예쁘고 깔끔해서 더 좋습니당~~~많이 파세요^^ㅋㅋㅋ'],
#  [0, '찢어져서 왔어요..냄새도 많이 나고 접착제 또 많이 먹어요...'],
#  [1,
#   '재구매 지난번에 구매했던곳인데, 다시 구매하게되었습니다. 재구매이유는 제품도 좋지만, 판매자분이 굉장히 신속하게 보내주시고, 꼼꼼하게 포장해주시때문입니다. 번창하시기 바랍니다.'],
#  [0, '분사노즐이 이상한거같음'],
#  [1, '보들보들 좋아요 아직사용전이예요'],
#  [0, '상품정보를 착각해서 구매했어요'],
#  [0, '잘안붙고 양이 낱게 판매같음 성능대비 바가지요ㅋ'],
#  [0,
#   '냉장 냉동 보관하라고 적혀있는데 상자에 그냥 왔네요? 이게 맞나요? 17개월 딸 주려고 샀는데 조금 두꺼워서(아기가 먹기에) 반씩 길게 잘라 줬어요 아가는 잘먹네요 워낙 고구마를 좋아해서'],
#  [1, '소재가 좋아요. 워싱된거같아요. 다리는 핏된 스탈이고 허리는 조금 크게 나온듯하답니다. 매우만족입니다.'],
#  [1, '정말 이뻐요 여름에 딱'],
#  [0, '그냥그렇다네요...'],
#  [0, '재구매 상품 하자있는거와서 죄송하다고 거치대 주신댔는데 보내주지도않고 연락도 씹으시네요.'],
#  [1, '맛있는데 많이 건조되어 부스러기가 많아요.'],
#  [1, '크기도 적당히 크고 맛있어요'],
#  [1, '포장이랑 시계가 너무너무 이뻐요'],
#  [1, '작은밥 조아요 딱이에요'],
#  [0, '접시가 너무 딱딱해요'],
#  [0, '안좋아요 각질도 오히려 심해졌어요'],
#  [1, '넘 좋네요 옷은 잘 구입하지 않는데 가격대비 넘 좋네요~ 길이 사이즈 모두 만족합니다 많이 파시고 번창하세요'],
#  [0, '퀸사이즈랑 같이 샀는데 색이 다르네요 더 푸른빛이 돌고 뒷면도 달라요 ㅠ'],
#  [0, '정말 필요한 명수만 결재하세요~ 수량 변경하려했더니 안된다하네요 돈이 아까웠어요'],
#  [1, '재구매 두번째구매예요.짜지만 적당히 물에담가두면 맛나요'],
#  [0, '재구매 이번에 LED로 잘 주문했어요 아직 쳐보지는않았는대 몇번치면 전구가 날라갈 것 같이 허술하긴해요'],
#  [1,
#   '오늘 바로 받아보고 리뷰써요 딸아이가 건선피부라서 항상가려워 하거든요 네이버쇼핑보다가 리뷰가 넘좋아서 구입합니다 스프레이만 뿌려봤는데 가려운데다 뿌려서 그런지 따갑다고 하더라구요 1주일정도 써보면 효과가 있다는데 진짜 효과 받았으면 좋겠어요'],
#  [0, '상품 판매이후 ,차후 as서비스까지 판매하시는만큼 신경써주시길 바랍니다.'],
#  [1, '아기 주려고 삿어요 굿굿 입니다'],
#  [0,
#   '상품평이 너무 좋아서 구매를 했는데 글쎄요 마트에서 구입한 것 보다 좀 구수한 맛이 있지만 이걸 마시고 나면 항상 배가 아파요 돈이 아까워서 여러번 시도를 했는데 마시고 나면 배상태가 안 좋아서 그냥 놔두고 있어요'],
#  [1, '티비가성비갑이라는 이유가 다있네요 정말좋습니다'],
#  [1, '선물용우로 매우 좋네요 추천 합니다 ㅎ'],
#  [0,
#   '동치미 무 보다 거의 국물 위주로 오는듯.. 박스안에 아이스팩있고 총 무게 딱 6.4키로네요 8.4리터통에 채운다길래 무 무게만 5키로인줄 착각했네요'],
#  [0, '사이드 안맞아서 안신어요'],
#  [0, '제질상태가 영 마음에안드네여'],
#  [0, '전체적으로 색상이 너무 어두워서 그릇에 음식을 담아도 맛깔스러워 보이지가 않네요..ㅜㅜ'],
#  [1, '배송빠르고 딱좋아요 인덕션에도 잘되고 대만족입니다'],
#  [0,
#   '배송도 느리고, 전면유리에 난반사도 일어나고, 뜨는 부위도 많고, 딱으라고 준 천에서는 이물질도 생기고 창문열면 바람에도 날리고... .. 파시는분 제대로 된거 만들어서 파세요~~'],
#  [0,
#   '저렴히 사서 그런걸까요 오늘 도착해서 바로 씻고 하나 붙였는데 촉촉함이 덜해요 ㅠㅠ 여태껏 쓰던 아이들은 촉촉하다 못해 척척했는데..그래도 저렴한 맛이 다 씁니다..'],
#  [0, '생각보다 사진이 많이 흐리네요'],
#  [0, '알러지케어라고했는데 저희아들도 저도 재채기하거나 비염증상와서 세탁 살균 건조기 다해봤는데 못덮는중이요'],
#  [0, '배송이 별로임;;;'],
#  [1, '랜덤발송은 충격적이었으나 핑크를 좋아하는 저로서는 뽑기 성공이네요 ㅋㅋㅋ'],
#  [1, '센카를 저렴하게 구매할수 있어서 좋습니다ㅎㅎ'],
#  [0, '색감이 정말 완전 달라요,,다크한 네이비를 살각했는데 파랑빛이 감하게 도는 네이비리 싼 티가 너무 나네요ㅠㅠ'],
#  [0, '매우 딱딱해요. 좀 더 물렁한것도 있던데 이건아니에요'],
#  [0, '상의는 맞는데 하의가 커요 무진장'],
#  [1, '파마약이 냄새도 적고 머리 손상도 거의 없는거같아요~근데 오랫동안 방치해야 머리펌이 잘 나올것같아요'],
#  [0,
#   '주굴주굴 수분기 있는 종이상자에 신문지 한장 달랑 깔려 옴. 상자를 열자마자 엄청 뚱뚱하고 샛노란 벌레가...헉....벌레도 생으로 먹으란건가요?? 무서워서 나머지 옥수수 껍질'],
#  [0, '아주좋네요 추천할게요'],
#  [0, '두시간을 뚫엇는데도 뚫리지않네요ᆞ역시 사람 불러야할것같습니다'],
#  [1, '유선에 비해선 충전시간이 1.5배 더 걸리지만 느리지만 사용이 편하네요'],
#  [1, '친구한테 보냈습니다 잘 받았다고 하네요'],
#  [1, '맛있어요 다음에 또 올게요'],
#  [0, 'ㅎ옹어워태ㅓㅌㅎ옽ㅌㅎ툐텅호웅홍ㅇ허엉ㅎ'],
#  [0, '포장좀 제대로 해주시지'],
#  [0, 'ㅑㅗ퓨ㅡㅏㅎ'],
#  [1, '존맛탱 잘받았습니다'],
#  [1, '깔끔하고 깨끗해서 너무 좋아요'],
#  [0, '너무 부실해요 안다가 넘어질것 같이요 모양만의자네요.'],
#  [0, '재구매 흐음.....두번째 시킨건데 하나가 맛탱이가 가서왔네요... 다른거 먹어도 되는건가싶은데...'],
#  [1, '애들이 중국산 김치를 좋아하는데 너무 맛있데요 ᆢ'],
#  [0, '충전케이블 없는 충전기네요 명확하게 설명되어있는데 제가 놓친건지... 초심을 잃지마시길'],
#  [0, '리뷰보고 주문 했는데 트리트먼트가 린스처럼 묽고 별로 였어요;;'],
#  [1, '만족 대만족 주파수만 맞춰서 연결하면 불루투스 오디오 내장안되어있어도 이렇게 좋습니다 하하하 블랙 색상도 세련되고 이쁘네요'],
#  [0,
#   '3세대 pd충전기인줄 알고 시켰는데 아니네요 한국에서는 4세대로 사야된다고 하네요 최저가 찾다가 확인못하도 구매한 제 잘못이지만 ...'],
#  [0, '마스크는 감사하지만 너무 얇은 케이스에 마감도 아쉬웠습니다'],
#  [1, '굿굿 편하구 좋아요.'],
#  [1, '좋아요 잘 사용하고있어욯ㅎ'],
#  [0,
#   '파스용은 아니에요 다들 좋다하셔서 구매했는데 뻐근한곳에 붙여봤는데 아무런 효과가 없어요 어떻게 다들 좋다하시는지 영 궁금하네요 이건 파스용도가 아니에요 파스용도로 구매 하시고자 하시는분은 구매 안하시는게 좋아요'],
#  [0, '온열 지속력은 나쁘지않은데 역시 향이ㅜㅜ'],
#  [0, '두께감있는 팬 잡을 때 불편해요'],
#  [1, '재구매 가격대비 가성비가 좋은 제품이네요.'],
#  [1,
#   '이건 아직 안붙여봤지만 예전에 빅쏘 강화유리 사서 잘 썼던 기억이 있어 구매했습니다. 사생활보호되는 유리부터 붙였는데 가이드틀이 있어서 붙이기도 쉽고 좋아요.'],
#  [1, '유럽여행 도난방지로 마련했는데, 갈수있을지 모르겠네요... 뭐 이번에 못가면 다음에 쓰죠'],
#  [1, '몸에 딱 잘맞네요 굿'],
#  [1, '시중 오프라인에서 30만원에 판매되는 제품과 같거나 상위느낌이고 디자인도 깔끔합니다'],
#  [0, '촬영하려고 걸어두었는데 툭 분리되고 색상도 맘에 안드네요 한달후기는 사용후에'],
#  [0, '그냥 없는것보단 낫네요'],
#  [0, '하늘다람쥐는 잘 사용하지 않네요ㅜㅠ'],
#  [0, '사진에 있는개수 다주는줄 알았는데 1개 가격이였네요 전 몰랐네요'],
#  [0, '안센다고 하더니 국물이 세더군요..'],
#  [0,
#   '칫솔꽂이 세트는 멀쩡이 왔는데 컵받침은 산산조각 나서 왓네요... 다른건 다 상자에 포장해주셨는데 쟤만 종이에 포장되서... 종이에 포장되면 당연히 깨지는거 아닌가여... 빠른 교환부탁드립니다'],
#  [0, '금방데워지고조음 배에올리니까 딱맞네요 찜질용으로잘쓰고있습니다~~~~^^ㆍㄱㄴㆍㄴ슨ㄲㅎㄷㅆㄷㅅㄷㅅㄷㅅㄴㅋㄴ그'],
#  [1, '배송 완전 빠름! 하루만에 왔어요 다른 곳보다 저렴하게 잘 산것 같아요'],
#  [1, '아주 좋아요.다음에 주문희망있습니다'],
#  [0, '무른것도 있었어요.새콤 달콤해요'],
#  [1, '조리원에서 쓰는거보고 꾸준히 썻는데..락스라니'],
#  [0,
#   '배송과 제품 문제로 별두개 감점 일단 제품 상태가 심각합니다 박스는 여기저기 터지고 테이프도 뜯어저있고 누가 사용했는지 갈린자국이 심하고 녹은 말할것도 없고 반품 할려다가 그냥 사용합니다 4만원이 싼거는 아닌데?'],
#  [0, '좀 단맛이 강해서 경상도맛이랑은 좀 먼듯'],
#  [1, '재구매 재구매합니다~ 믿고구매해요~ 아기한테 먹이기 좋아요. 양도 넉넉해요'],
#  [0, '너무 심한 핑크예요 상품 사진과 완전 달라요 ㅠㅠ'],
#  [0, '거품이 잘 안나요 샤워시 중간에 펌프를 네다섯..번 이상 해야되네요'],
#  [0, '재구매 아직 써보지는 안않는데 괜찮을거 같아요'],
#  [1, '저렴한 가격에 구매 했습니다.'],
#  [1, '빠른배송 좋쿠요 제품은 아직 사용해보지 못했습니다..'],
#  [1, '아이패드 12.9 3세대에 충전 잘하고 있습니다 가격이 좀 쎈것만 빼면 만족도가 높아요 아 그리고 쫌 무거워요 ㅋㅋ'],
#  [0, '허리 지지대가 차라리 없었으면 나았을듯'],
#  [1, '편하고 핏이좋아용^.^또이용할게요'],
#  [1, '배송은 꽤 늦었지만 잘먹을게요'],
#  [0, '가격값을 하네요, 가방 끈 연결하는 부품이나 안내도 없고 냄새나고 딱 가격이 싼 이유 그대로 에요'],
#  [0, '기장도 맘에안들고요 목선도 너무받트구요 품도 너무타이트하고요 모든게다 별로 산것을후회했네요 역시 사진으로만보고사는게아니었어요'],
#  [1, '득근득근득근 해진다 득근득근'],
#  [1, '여름마다 많이씩 구매해서 청 담그고 있어요. 가격도 착하고 상태도 좋아서요.'],
#  [0,
#   '다른건 크게 불만이 없는데 자석이 너무 약해서 잘 떨어져요 반만 붙이거나 하기가 힘들정도로 약해서 아쉬워요. 뒷자석에는 펼쳐서 쓰면 사진처럼 쓸수는 있습니다. 앞좌석은 잘 떨어지네요 .. 흠'],
#  [1, '가볍고 막쓰기 편해여'],
#  [1, '기대 이상이에요 숫자도 넉넉하고 생각했던 것보다 괜찮아요. 숫자 뜯다가 힘줘서 부러진것 빼고는 좋아요~~<'],
#  [1, '활용도가 좋아서 외출시에는 필수지참 ㅎ'],
#  [1, '좋아요 안맞으면 어쩔까 고민했는데 편해요 시트도 적당히 푹신해서 좋고 아주 만족스럽습니다 배송도 빠르구요'],
#  [1, '재구매 튼튼해서 하나또구매했어요'],
#  [1, '허벅지랑 엉덩이가 커서 라지했는데 잘 맞아요~ 밑위가 조금 짧네요 ㅋㅋ 워터파크 필수템!!'],
#  [1,
#   '전라도 맛있는 배추김치 제가 호텔 김치도 사다 먹어 봤는데요 이 김치가 쵝오 맛나요 인공 조미료의 그런 자극적인 맛 아니고요 젓갈 가득한 싱싱한 전라도 김치예요 정말 김치에 손이 자주가요 머는 김치요리는 다 해먹고 싶네요 계속 여기서 먹을거예요'],
#  [0, '저렴한 중국산 제품에 부품을 쉽게 구할 수 있어 좋습니다만 미세먼지땜에 계속 중국산 쓸 수가 없을 것 같아요.'],
#  [0,
#   '애들 방에 해줬는데 소음이.너무 심해요. 엄청난데요... 물흐르는 소리는 참는다해도 너무 시끄러워요. 항상바빠서 신경안쓰다가 애들방에서 누웠는데 소리 장난아니네여. 판매자분도 이거 방안에서 사용가능하신가요?'],
#  [0, '진짜 그저그래요 쩝'],
#  [0, '너~ 무 뻑뻑해서 손톱 다듬기 힘듭니다.. 후회됨..'],
#  [0, '고추씨가그대로들어있어 먹기매우불편함'],
#  [0,
#   '사이즈가 생각보다 크네요 상품설명에 있는 사이즈보다는 큰것같고 열자마자 고무냄새가 너무 심해서 바로 페브리즈 뿌려서 베란다에 냄새빼려고 놔뒀네요 아직 설치전입니다.'],
#  [1, '재구매 일년 사용중 잘 쓰고 있어요'],
#  [1, '재구매 목 넘긴편하고 냄새도 안나요 기한도 넉넉해 두번째 이용중이네요 ^^'],
#  [1, '재구매 항상 재구매합니다 굳굳'],
#  [0, '4일차쯤 와이파이 속도가 극도로 줄어서 카톡도 안보내질정도로 느려져서 남은 5일동안 사용못했습니다'],
#  [0, '한번세탁햇는데 접착 부분이 떨어졌어요'],
#  [0, '그냥 그런것같아요~'],
#  [0, 'ㅠ 다리털도 못뽑아요 ...'],
#  [0, '다음에는 유통기한 신경써서 보내주셨으면 합니다~~~~~!!!'],
#  [1, '양말 괜찮아요 재구매 의사 있습니다'],
#  [0, '명함의 절단면이 정확하지 않은게 많이 보여요..골라서 사용해야할듯해요. 아무리 오차가 있다지만 다음에는 절단면 신경써주세요..'],
#  [0, '별로임 배송이느려 다른 제품으로 구매했음창고에 던져버림 앞오 배송에도 신경써주기 바랍니다 수고하세요'],
#  [0, '청소포 봉투가 뜯어지고 새고 정상적이지 않아 난감.'],
#  [0, '리빙박스에서 냄새가 너무 심하게 나요. 집에서도 나서 머리아픔'],
#  [1,
#   '회사에서 사장님께서 드신다고 주문해달라셨어요! 언제 먹는게 좋은지 같은게 적혀있으면 좋을것같네요! 드셔보시고 다음에 다시 리뷰 남길게요!'],
#  [1,
#   '판매자님 친절갑 긴거랑 짧은거 두개 샀어요 제품 딱 보기에도 튼튼하구요 판매자님 서비스 또한 친절해요 넘나만족합니다 이게 망가질 일은 드물겠지만 덜렁대다 잃어버리면 다시 여기서 구매할 생각입니다'],
#  [0, '왜 이러죠? 교환해주세요'],
#  [0, '부가 가격부분을 명확하게 해주면 좋겠네요'],
#  [1, '배송이참빠르네요 기저귀 정리하려고 급히 주문함 ㅋ'],
#  [0, '그냥 그래요. 왔는데 손잡이에 기름이 엄청 뭍어 있어서 찝찝했음. 성능도 그닥.'],
#  [1, '배송 빨랐구요 아이 수영가방으로 샀는데 활용도 좋을것 같아요'],
#  [0,
#   '바빠서 박스포장 사진을 못찍었는데 테이프 제대로 아발려서 박스가 거의 개봉된 상태로 도착당시 아이스백은 다 녹아있고 좋은 상품 기대하며 오래 기다렸고 비싼 제품 일부러 구매했는데 대실망입니다!!!'],
#  [1, '재구매 닭다리살 항상 너무 맛있어요~~~ 구어먹고 삶아먹고 양념구이 해먹고 가격도 싸고 굳굳!'],
#  [1, '크고 많이들어가서 좋네요'],
#  [0, '전반적으로 작고, 옷 재질이 싼티가 좀 나는 것 같아요.'],
#  [1, '촉촉하고 부드러워 너무 좋습니다 ^^'],
#  [1, '재구매 호수 변경하는데 빨리 처리되서 좋네요 매번 구매하지만 항상 만족합니다 ㅋ'],
#  [0, '평이좋아서 구매했는데 저희강아지는 빨갛게 붓고 세정해도 냄새남아있네요..'],
#  [0, '한번뽑을때 세장은 기본으로 뽑힘'],
#  [1, '재구매 마늘맛 최고에요! 닭가슴살 먹기 쉬워요'],
#  [1, '이너로입으면티안나고확실히전후다르긴하네요'],
#  [0,
#   'pvc 헤라 사이즈도 잘못 배송되었고. 또 하나는 끝 부분이 파손된 상태로 배송되었네요. 사이즈나 끝부분은 작업할때 꼭 필요해서 선택한건데 아쉽네요 ㅠㅠ'],
#  [0, '밀웜 택배로 받아보니 폐사 일보 직전 입니다. 상태가 너무 않좋아요 30%는 죽은것 같아요'],
#  [1, '맛있어요 또사먹고싶어요!!!너무너무맣있엉요픅흐그흐ㅡㄷ근데너무비싸여초코갖제일맛있어ㅛ어여하하핳최고!!!'],
#  [1, '후방 카메라 화질이 기대보다는 좋지 못한 것 같으나 가격을 보면 이해가 됩니다.'],
#  [0, '완전 불친절하세요'],
#  [0, '재구매 .. 커클랜드요거트 좋아하는데 이번꼬는 알갱이가 엄청 나와요.. 식감도 소름돋고 그릭요거트가 아니라 그냥 요거튼것같아요'],
#  [1, '무거워서 둘이 들던 테이블 이제 혼자 끌 수 있어 좋아요'],
#  [1, '상의, 하의 기장 자를필요없이 딱딱딱입니다.'],
#  [0, '이틀도 안되어 가방에 있던 부착물이 떨어짐 약하게가방을 만들고 입구도 좁아 불편함'],
#  [1, '거품이 많아서 좋습니다.'],
#  [1,
#   '👍🏻👍🏻👍🏻 초록이로 한개샀다가 너무맘애 들어 연잎으로 재구매했어요 저는 두개다 하자없는걸로 잘받았구요 연잎 첫인증으로 연잎위에서 밥먹었어요^^'],
#  [0, '아쉽네요 너무나 기다리고 기다렸는데 설치하려니 참문틀에 굴곡이 약간있니 자꾸빠져서 사용하지 못하네요 ㅠ'],
#  [0, '설치하려고. 했으나 실패했네요.제차에는 설치가안돼요 맞질안네요.반품할까하다가 휴지통에 버렸어요.'],
#  [1, '뭐 한두달용으론 이만한게 없는듯 근데 생긴거완 다르게 생각보다 오래 못써요 ㅋㅋ'],
#  [1, '소음이 다소 있지만 퍼팅 연습하긴 좋습니다'],
#  [0, '만족따뜻해요..안에 피쓰쪽부셔져서달그닥소리나서 반품보낼려다가귀찮아서 다풀고 안에 플라스틱 부셔진조각빼서그냥씀.귀찮아서.'],
#  [0, '깜짝놀랐어요 어찌나거친지 시원하기는커녕 등에 상처가났어요~~~~~~~'],
#  [0,
#   '하..지금 확인했는데 나머지 두개는 정상적으로 왔는데 하나는 바락식혜 시켰는데 컨피던스 왔어요.. 당연히 식혜왔을줄알고 며칠 확인안하고 있다가 지금 봤는데 일단 그냥 먹긴하겠는데..다음부터 확인 잘해서보내주세요ㅡㅡ'],
#  [1, '배송도 굉장히 빠르고 부품 완성도도 높아 아이가 즐겁게 만들고 있어요'],
#  [0, '손등형인데 왜 엄지 손가락 나가는 구멍이 없죠?'],
#  [1, '매일 사용하고 있어요~ 디자인과 크기 기능 모두 맘에 듭니다~'],
#  [0, '오토바이용인데 떨림오인식이...'],
#  [1, '오크야 말할것도 없고, 디썸 압분 가성비 좋네요'],
#  [1, '조아요 이뻐요색상도'],
#  [0, '저렴 저렴해서 구매했는데.. 음... 한번 사용하니까 코팅이 다 일어나고 쓰지 못하겠네요. ㅠㅠ'],
#  [0, '상품평들에 너무기대를 했어요'],
#  [0, '젖꼭지솔은 너무거품도안나고안닦이고젖병솔은너무크고완전별루입니다비싸기만하구'],
#  [0, '호박씨에서 냄새나요 교환 귀찮아서 그냥 먹어요'],
#  [1, '재구매 까칠한딸내미 입맛에도 좋다고하네요~~^^'],
#  [0, '사이즈 66인데.. 좀 타이트해서ㅡ 입고 벗고 불편해요..그치만..날씬한분들은..가슴모양도 이쁘게 표현될듯해요.'],
#  [1, '케이스 디자인 넘 예쁘네요에'],
#  [1, '소간은잘먹는데 돼지귀는딱딱해서그런지 잘안먹네요 물에불려서먹여볼려구요 양이엄청 많아요'],
#  [0,
#   '최악 배송 8일걸림 해외배송도 아니고 휴일 하루 끼어있었는데 이것보다 늦게 주문한 상품도 다 왔는데 겁나 느리고 포장도 개판 다 찢어지고 뜯어저서옴 최악'],
#  [0, '너무 불편해서 사용 안 함'],
#  [0,
#   '배송요청시간 1시간40분 지나서 받는분이 사진 전송해줬네요.. 그냥 문자 안보내도됩니다. 그리고 12.금전수 식물이 부실하네요..'],
#  [1, '아빠선물로 구입했습니다. 세트로 예쁘게 포장되어 있어서 좋았습니다! 다음에 또 구매할게요!'],
#  [1, '배송빠르네요.. 튼튼합니다.'],
#  [1, '드레스업하고 사용하기좋아요'],
#  [1, '좋습니다 배송도 빠르게 잘받았습니다 사은품도 충전기 파우치 좋습니다 깔끔합니다~사용하기도편해요~!!'],
#  [1, '사진 그대로 입니다 귀엽고 예뻐요'],
#  [1, '사이즈도 정사이즈인거같고 핏도이뻐요'],
#  [0, '통이 닫는 부위가 잘 안 맞네요 ㅠㅠ그냥 써요'],
#  [0, '사진과달리 잎이 너무 휑하더군요'],
#  [1, '점이 생각보다 강해서 한번 제대로 해보고나서 재구매를 결정할것 같아요'],
#  [1, '입어보니 편안해서 좋네요'],
#  [0, '거치링이 사이즈가 안맞네요 사용을 못합니다'],
#  [1, '지금 입기 딱 좋은 두께에 부드럽고 좋아요'],
#  [1, '피부가맑아쟈요'],
#  [1, '가격만큼은 하네요. 잘 받았습니다.'],
#  [1, '배송빠르고 가격 마음에 듭니다'],
#  [0, '차량의 어디에도 끼울수가 없네요'],
#  [1, '깔끔하게 연결돼서 좋아요!!'],
#  [0,
#   '2단케잌..45-46개들어간다고해서 딱그만큼만현금바꿨는데.... 촘촘하게한것도아닌데.ㅜㅜ49개들어가서.. 또바꾸러가고바빴네요 문구가잘못왔어요 이미글씨판거라 교환도안될거고 미치긋네여. ㅡㅡ'],
#  [0, '한쪽이 자꾸떨어집니다'],
#  [1, '감사합니다! 좋은선물할게요'],
#  [1,
#   '얼굴에 흉이 져서 평소 메ㄷ* 사용 했었는데 지인이 시카케어는 효과도 좋고 씻어서 쓸 수 있다는 이야기를 듣고 구입 했습니다. 이틀째 인데 빨리 흉터가 나아 졌음 좋겠습니다.'],
#  [0, '휴..포장상태엉망ㅇㄱ너'],
#  [1, '믿고쓰는 바세린이죠! 감사합니다.'],
#  [1, '은은하게 색 이쁘구요 봄에하기좋구 재질 좋습니다 색은 사진 그대로입니다~'],
#  [0,
#   '생각보다 복숭아뼈도 아프고 볼도 크게니와서 저에게는 조금 별로이네요... 그래도 굽이 조금있어서 가끔 신을려고 반품은 안했지만..딱 그가격에 맞는 상품같습니다.'],
#  [0, '배송상태가 별로에여 냉동인데 다녹음'],
#  [1, '매일우유를 아기가 젤 좋아하고 잘마셔용 믿고 마십니다용'],
#  [0, '당일배송이라고 해서 금욜에 시켰는데 토욜 파티때쓰지도 못하고 오늘 받았네요...쓸모가 없어진. ㅠㅠ'],
#  [1, '부모님이 바로 연결해서 사용하시는데 무리없을정도로 바로 세팅이 되어서 와서 너무 좋았습니다.'],
#  [1, '조리원에있으면서 구매했는데 짱짱하니 좋네요.'],
#  [0, '재단도 배송도 정확한데 볼트를 박아야 하는 나무 끝 부분이 반쯤 없어서 결국 그 부분은 버리고 나무 사다가 다시 만들었네요~'],
#  [0,
#   '사진으로 보이는것보다 핏이 별로였습니다. 얼굴이 너무 다 가려지고 생각했던 벙거지 모자라기에는 모자챙인 아래부분보다는 윗부분이 너무 길어서 중절모 느낌이에요...'],
#  [1, '부모님이 드신데서 구매했습니다~ 맛있고 간편해요'],
#  [1, '애기가 잘 물어서 필수에요'],
#  [0, '너무얇아서아쉬웠어요'],
#  [1,
#   'PS4에 연결하여 사용하고 있습니다. 게임 로딩이 반이 되어 몹시 만족스럽습니다. 사이즈도 작아서 은엄폐하기에 좋습니다. 유부남, 엄빠눈치보는 학생들에게 강추합니다.'],
#  [1, '디자인도심플하고 가격대비제품질도좋은거같아요 한가지아쉬운점은다리색깔이아이보리입니다'],
#  [0, '배송관련해서 업데이트가 정말 너무 느려서 답답했습니다.'],
#  [0, '더 심해지는 느낌은 왜일까요?ㅜ 성분이안맞는건지..ㅜ 일단 더 써봐야겠어요'],
#  [0, '접착력이 너무 약하네요.. 스스로 잘 떨어지네요ㅡㅡ'],
#  [1, '매번 아주 잘쓰고있습니다. 착한가격 감사해요'],
#  [1, '사이즈가 커서 좋습니다 홈쇼핑 고등어 두배는 될거같네요 재구매 의사 있습니다~~^^'],
#  [0,
#   '베트남 현지에서 먹은 베트남고추는 건고추가 아니라서 그런지 매운맛도 좋고 텁텁한 없어서 한국산보다 더 맛이나서 주문하였으나. 건고추가 원래 매운 맛도 잘 안나고 맛이 없습니다.'],
#  [0, '조리원 나오고 지금은 3주차인데 1단계 사이즈가 딱 맞네요. 무난하게 쓰기 좋고 찍찍이 정말 강하네요.ㅎ'],
#  [1,
#   '좋아서 재구매합니다 지난번에 사고 맘에 들어 재구매했어요~ 배송도 빠르고 제품도 편하고 시원해서 좋아요! 다음에 또 사러 올게요~~'],
#  [0, '밀착이 되지 않아 서류가 잘 빠집니다.'],
#  [1, 'ㅐ좋아여주태누타ㅡㅋ'],
#  [0,
#   '고장 났음 몇번 쓰지도 않았는데 베터리그 충전 중이면 무선 충전고ㅓ 케이블 충전이 작동 하나 고장나서 무선충전 유선충전 둘다 동작이 안함 가격에 싸면 이유그 있는듯'],
#  [0,
#   '우선 재질도 튼튼해보이지 않으며 제일 문제는 각도가 제대로 꺽이지않아 여로모로 불편하고 폰거치부분의 폭이좁아 케이스끼고는 넣을수가 없어서 도로 달리다가 던져버리고 싶었음'],
#  [1, '쫀득거림이 너무 좋았어요 배송만 더 빨리왔으면 더 좋았을것같네여'],
#  [0, '마감이 깔끔하지 않아요'],
#  [1,
#   '허벅지부분 약간 조이긴하는데 제가 허벅지가 좀 있는 편이기도 해서 입다보면 늘어나겠죵? 사각심리스는 처음 입는데 진짜 편하네요. 만족스럽습니다.'],
#  [1, '포장도 너무 잘되어서 왔구요~ 보증서 소독솜 손편지까지 이렇게 해주시니 믿고 구매하는거 같아요~^^'],
#  [1, '재구매 매우빠르고 좋습니다. 구매하세요'],
#  [1, '맛있어요 구매할생각하다가 생각보다 비싸서못했는데 세일딱하길래 바로구매했지요~ 맛보니 진짜과일간맛이나요~만족합니다'],
#  [0, '좋아지는지 솔직히 잘 모르겠네요.. 암튼 효과 없습니다.'],
#  [0, '만족해요.'],
#  [1,
#   '거품이 하도 안나서 되는건가 마는건가 했는데 말리고 나면 또 부드러워지더라구요? 신기... 특히 향이 좋아요. 끝까지 잘 쓸 수 있을 거 같습니다.'],
#  [0, '양쪽 뼈대에 볼트 넣는 구멍이 서로 다름 환불하려다가 말았음 불량이 올 줄 상상도 못함'],
#  [0, '효과 하나도 없음 100% 사기입니다'],
#  [0,
#   '중국에서 바로들어오는제품이라 중간에 품질테스트없이 바로 고객에게 발송되니 불량이 많음 불량교환또한 또불량 100프로 상태좋은제품으로 받기까진 길고긴시간의싸움'],
#  [0, '정말 반품하고픈 제품을 보내주고 어쩔수 없이 제품을 개봉해서 확정하지만 너무 실망스러운 제품입니다. 절대 구매하지마세요'],
#  [0, '하이그로시 재질에는 자국이 남음'],
#  [0, '빨면 레이스 다 뜯어짐'],
#  [0, '재구매 의사는 없네요.'],
#  [0, '냄새가 너무 이상하고 펌프하면 너무 확 나와서 액체가 땅에 떨어지네요.'],
#  [1, '생각보다 작긴하지만 데일리로 쓰기에 딱 좋아요~^^ 깔끔합니다'],
#  [1, '맛있어요~ 냉동실에 막 꺼내서 떡 물에 불려서 해먹으니 맛있어요^^'],
#  [1, '조금더 작은 사이즈 있으면 좋겠어요'],
#  [1, '기저귀 유목민중 리프가닉 써보고 좋아서 구매했어요 잘 맞기를!'],
#  [0,
#   '실망이예요ㅜ 제대로 검수를하지않은건가요?ㅜㅜㅜ 한쪽소매의 단추가 안잠겨져요ㅜㅜㅜ 튀어나온쪽의단추가있어야하는데. 둘다 똑같이 되어있네요 아....디자인은이쁜데ㅜㅜㅜ 먼가요이건 수선비가 더들게생겼네요ㅡ...'],
#  [0,
#   '구매한 제품 4개 엿는데 3개만와서 문의글에 남겻더니 사진찍어 보내달라해서 보냇는데도 제품 안보내줘서 연락 햇더니 연락두절.. 제대로 확인하고 보내세요. 사기당한 기분이네요'],
#  [1,
#   '향수디자인처럼 매우 고급스러운 남자 향이납니다. 정장 수트입고뿌리면 어울리는 그런향이랄까요 매우 만족입니다. 향도 매우 오래가요'],
#  [0, '죽어서 왔었어용 ㅠ'],
#  [1, '나이드신 엄마가 사용할것이라서 투명한것을 원했는데 사이즈도 적당하고 딱 찾는 스탈여서 좋아요'],
#  [1, '배송이 늦었지만 맛있게 먹었어요'],
#  [0, '먼지 대박 진짜 세탁 건조기에 먼지덩어리가 토하도록 나오고 나른 빨래감까지 먼지 구덩이 됨 비추'],
#  [0,
#   '색상 이쁜데 냄새가 심해서 머리가 아프네요 틀 잡아야 한다고 세탁하지 말라고 써 있어서 세탁 안하고 그냥 씌었는데 냄새가 너무 세요'],
#  [1, 'ㄱ디니디딛ㅅㅌㄱ디디ㅣ'],
#  [1, '회사 업무용 가방으로 구매했어요~ㅎㅎ'],
#  [0, '싼게 비지떡 !!!!!! 배송도 느리고 ... 첫날부터 보프라기일어나고 재구매 절대 안할듯하네요'],
#  [1, '실내자전거를 3주눌러놨는데 자국이 금방 사라져서 좋네요'],
#  [1, '엄청 튼튼해보이고 높이조절이 보여서 좋아요'],
#  [1, '처음 주문해봤는데 효과 있었음 좋겠어요~^^'],
#  [1,
#   '정말 맛잇어요~ 뱃꼽살이랑 오도로 시켯는데 둘다 너무 맛잇어요 양이 엄청 많아요~ 집들이나 파티때 시켜드시면 너무 좋을거 같아요~!'],
#  [0,
#   '수납공간도 넉넉하고 깔끔하니 예쁜데.. 다만 문짝 모서리에 흠집이 크게 났더라구요. 날이 더워서 풀칠?이 녹아서 모서리 부분이 찍혔는지 움푹 패이고 끈적해요. 싼맛에 구입한거라 교환도 귀찮고 해서 그냥저냥 쓰려고 합니다.'],
#  [1, '냄새좋고 진짜 가성비 짱 넘조요 또구매할께요'],
#  [0, '생각보다 퀄리티도 않좋고 판매자와는 단 한번도 연락이 닿지 않네요'],
#  [1, '재구매 괜찮게 상태 나쁘지 않아서 잘 먹었어요'],
#  [1, '전에 써봤는데 좋았어서 또 시켰어요.'],
#  [1, '아기가 잘 입어줄지 모르겠지만 디자인이랑 예뻐요 뒤에 똑딱이로 되있어서 편할 것 같구요'],
#  [0, '뚜껑이 안열려요..ㅜㅜ'],
#  [1, '선물해 줬는데 정말 잘 먹었다고하네요^^ 다시 재구매 했어요~'],
#  [1, 'QOTHD빠르네요 ㅋㅋ'],
#  [0,
#   '재구매 저 왠만하면 안쓰려고했는데 몇번 주문하고 괜찮아서 또 주문했는데 이번건 최악이네요진짜. 멍든것도 두세개있고 속이 저런것도 몇개 더있어요. 3분의1은 버린것같아요. 마트에서 다시 사와서 청담았네요.'],
#  [0, '좋은 먹거리지만 시판보다 맛이 없는건 어쩔수 없네요. 짠맛만 납니다.'],
#  [0, '포장없이 그냥왔지만 다행히 안깨졌어요'],
#  [0,
#   '싸서 그런지 진짜 후지고 매트도 딱딱하고 배송도 거칠고 진짜 배송기사 지꺼 아니라고 대충 막하던데요. 다신 동서가구 안사 시몬스 살껄 줮나 후회함'],
#  [1,
#   '일본가위를 넘어서♡ 일본의 분해 되는 스뎅가위 시가 5만원 전후의 그 가위를 ;; 장바구니에 넣은지 수 개월;; 오복 가위를 발견 했다죠~ 완전 좋아용 2주 후에 오사카 여행 가서 직접 그 가위 사올건지 말건지 저울질 중임니다'],
#  [0,
#   '포장은 잘되어 있더라구요 깨진 계란 하나도 없고 근데 알아 너무 작네여 일반 계란이랑 비교했는데 너무 조그매서 매추리알같네요 진짜 왜이렇게 알이 작나요???? 진짜 산거 후회해요'],
#  [0,
#   '고기가 맛있다고 하신분들...믿고 구매했는데... 저울달아보니 그램수도 안맞고 고기도 질기고.. 고기팩안에들어있는방부제까지포함 600g인가요ㅇ???'],
#  [1, '만족합니다^^ 포장도 꼼꼼하고 괜찮아요~'],
#  [0, ',냄새 너무 심하고..마감이 부실해요..리모컨 넣다 빼니 하얗게 먼지가 대박 ㅠㅠ'],
#  [0, '재구매 배송 완전 꽝입니다 매번 깨져서 오네요.!'],
#  [0,
#   '프라이머 도포 후 도색하는데 2차 도색 후 마스킹 테이프를 떼어내자 마스킹 테잎에 다 붙어서 도색이 떨어져 나오네요 깔끔하게 떨어져 나오는 것도 아니고 표면이 지저분하게 떨어져 나왔습니다...'],
#  [0,
#   '재구매 아이스박스에 핫팩 하나 안들어있고 죽은아이들 보니 속상하고 기분 나쁘네요 반이 죽고 괴사가 진행되서 반쪽없는 아이들이 많아요 기분 나쁘네요 ㅜㅜ'],
#  [0, '깔대기랑 같이 주문했는데 사이즈가 안맞아요. 이런건 신경써서 보내주셨으면해요'],
#  [0, '꿀고구마를 주문했는데 밤고구마가 와서 너무 퍽퍽하고 별로네요.. 시기가 그래서인지.. 어쩔수없이 그냥 먹고 있습니다.'],
#  [1, '안 잃어버리려 큰 우산샀는데 결국 잃어버렸내요ㅠㅠㅠ 그래도 좋아서 재구매합니다'],
#  [0, '필기하기 불편합니다'],
#  [1, '너무좋아요ㅜㅜ 소리도 작구 성능도 다이슨하고 별차이 못느끼겠어요^^'],
#  [0, '너무약해요ㅜ 옷걸어 두고 살짝 치면 쓰러짐ㅋㅋㅋ'],
#  [0,
#   '폭이 좁은데다 4단으로 하니까 하중도 못버티고 휘고 바퀴 빠지고 쓰러지고 난리났네요. 구석에 박아뒀어요. 가로폭을 좀 넓히시고 마감에 대해서 신경좀 쓰셔야 겠어요'],
#  [1, '유통기한 긴것으로 보내주셨네요^^감사합니다^^'],
#  [1, '차가조용해진거같네요'],
#  [1, '이사할때 도움 많이 되었어요'],
#  [0, '저렴해서 구입했지만 기대감이 있었는데 아쉽네요'],
#  [0, '냄새가 정말 아저씨 향수 보다도 못한 냄새임 한번쓰고 버림'],
#  [1, '잘 샀어요 또 규매 할게오'],
#  [1,
#   '구입하고 나서 가격이 내려서 별하나 뺐어요~ㅋ 닥터로드 마스크가 사용하기 편해서 주문했습니다~ 잘 사용 하고 재주문 할께요~^^~'],
#  [0, '괜히 큰것 했나봐요 너무 커서 좀 부담스러워요'],
#  [0,
#   '핸드드라이버는 별로네요 저가라 어쩔수없다하네요 동영상 보시면 회전시 이상하게회전하는데 정상이라고하네요 볼트 조이고할때 회전을 이상하게하니 힘을주면 빠지거나 이가나가네요 참고하세요'],
#  [0, '하자있는 상품 제값 다받지마시길'],
#  [0, '포장은 잘되어 있어서 기대하고 음식을 했는데 싱싱하고 시원한 맛이 없어요. 산지 직송인데 실망이 큽니다.'],
#  [0, '잘 찝히지도않고 별로에요'],
#  [1, '예쁘네요^^ 퀸사이즈 넉넉합니당'],
#  [0,
#   '다리 나사가 헐겁습니다. 교환하기 귀찮아서 그냥 써요,, 롯데 몰에 갔는데 똑같은 제품이 5천원 더 저렴하네요 ㅡㅡ 그리고 제품에서 냄새가 좀 나네요 오래 안써서 빠질진 모르겠네요'],
#  [0,
#   '야채다상하고 짓물러져있고 과메기에 비린내가 나는건알지만 그정도로 심하게 날줄은 정말상상을못했네요 제꺼만그랬던건지몰라도 저는 진짜최악이였습니다'],
#  [0, '리어쪽에 장착 안됩니다'],
#  [1, '아직 몇일안되서 잘모르겠지만 배송은 빨라요'],
#  [1, '잘집혀요~~만족스럽게 잘쓰고있습니다'],
#  [0, '아기 몸무게가 10kg지난 2단계를 주문해서 딱 한번 사용했어요. 아기가 거부를 해서 착용만 하고 사용 못하게 됐어요.'],
#  [1, '평소 갖고싶던 캐릭터가 피규어로 저렴하게 나와 구매했네요~'],
#  [0,
#   '한 달을 써봤습니다. 저는 무쌍이고 유분은 보통인 편이에요~ (기름종이 or 팩트 사용 No) 오전 9시쯤 바르고, 오후 3~4시쯤 되면 다 번져 있습니다.... 가루날림도 많고요 ㅠㅠ 가격 때문에 별 2개예요....'],
#  [1, '아주 편해요 또 구매 할게요!!'],
#  [0, '한개는 사용했고, 한개는 적용되는 기종임에도 안되서 못썼어요..'],
#  [0, '비추입니다'],
#  [1, '깔끔하니 좋아요 외관상 그냥둘까 고민하다 구입하게 되었습니다.디자인도 이뿌고 깔끔하니 너무 좋네요.적극 추천합니다.'],
#  [1, '재구매 합배송 문의시 시간이 다소 소요되는 상품에 한해서 미리 코멘트를 주시니 구매하기가 수월해요! 빠른배송도 역시 감사합니다'],
#  [0, '브라가 착용감 별로고 입었을때 안예뻐요'],
#  [0, '연료필터가 작업중 부러져서 새로 구매했습니다. 플라스틱이라 약한데 금속이었으면 좋다는 생각.'],
#  [0, '빠른배송에 감사드리지만 제품두께가 두꺼워서 핀이 바닥 코너에 붙여지지 않아 매끄럽지않게 시공되지 않네요'],
#  [0,
#   '상품은 좋습니다! 배송이 너무 아쉬웠어요.. 3월1일날 주문했는데 배송까지 한달 넘게 걸렸습니다..! 상황이 상황인지라 배송이 늦어지는건 이해하지만, 지금 구입 하실 분들은 참고 하세욥~!'],
#  [1, '색상이 화면보다 탁해요 오렌지색은 아니예요.. 다른건 만족합니다~'],
#  [0,
#   '파일로 힘줘서 해도 잘 안갈아져요. 그냥 손톱가위로 자르는게 낫고요~헤이큐티가 펄이랑 섞인건데 펄스티커만 자연스러워요. 다음부턴 그냥 매니큐어 바를거 같아요. 가장자리도 잘 뜨고..더 얇아야될거 같아요'],
#  ...]

# %%
def Tokenize_and_Posing(text):
    # INPUT = string
    
    from konlpy.tag import Mecab
    mecab = Mecab()
    mecab_tokenized = mecab.pos(text)
    
    # OUTPUT = list
    return mecab_tokenized

# %%
import pandas as pd
data = pd.DataFrame(result)
data1 = list(data[1])
data1
data2 = list(data[0])

# %%
x_train = data1
y_train = data2

# %%
#from konlpy.tag import Mecab
import nltk
stopWord = ['ㅋ',',','^','ㅠ','ㅡ','ㅎ']
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
# CountVectorizer 선언
count_vect = CountVectorizer(stop_words=stopWord, tokenizer=nltk.word_tokenize)
# fit and transform
x_train_counts = count_vect.fit_transform(x_train)
# MultinomialNB 선언 and fit
clf = MultinomialNB().fit(x_train_counts, y_train)

# %%
import pickle

filename = 'model/finalized_model.sav'
pickle.dump(clf, open(filename, 'wb'))

# %%
#from konlpy.tag import Mecab
import nltk
stopWord = ['ㅋ',',','^','ㅠ','ㅡ','ㅎ']
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
# CountVectorizer 선언
count_vect = CountVectorizer(stop_words=stopWord, tokenizer=nltk.word_tokenize)
clf = MultinomialNB().fit(count_vect.fit_transform(x_train), y_train)

# %%
import pickle

filename = 'model/a_model.sav'
pickle.dump(clf, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))
pd_e = count_vect.transform(['추천'])
result = loaded_model.predict(pd_e)
print(result)
# Out:
# [1]

# %% [markdown]
# ### 해당 카테고리 제품 ID list 획득

# %%
# 해당 카테고리 제품 ID list 획득
def get_items(category):
    page_num = 15 # 사용자 지정
    result = []
    base_url = 'https://www.oliveyoung.co.kr/store/display/getMCategoryList.do'
    url = 'https://www.oliveyoung.co.kr/store/display/getMCategoryList.do?dispCatNo=1000001000100010001&fltDispCatNo=&prdSort=01&rowsPerPage=24&searchTypeSort=btn_thumb&plusButtonFlag=N&isLoginCnt=0&aShowCnt=0&bShowCnt=0&cShowCnt=0'
    for i in range(page_num):
        params = {
            'dispCatNo': category, # 카테고리 ID
            'prdSort': '01', # 인기순
            'pageIdx': i + 1, # 페이지 번호
            'rowsPerPage': 24 # 한 페이지에 표시할 상품수
        }
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.102 Safari/537.36'
        }
        resp = requests.get(base_url, params=params, headers=headers)
        soup = BeautifulSoup(resp.text)
        prd_list = soup.find_all('a', class_='prd_thumb goodsList')

        for prd in prd_list:
            result.append(prd.get('data-ref-goodsno'))

    return result

# %% [markdown]
# ### 제품 정보 획득

# %%
# 해당 카테고리 제품들 정보 획득
def get_items_info(prd_list, category):
    prd_url = 'https://www.oliveyoung.co.kr/store/goods/getGoodsDetail.do'
    result = []

    for prd_id in prd_list:
        temp = {}
        params = {
            'goodsNo': prd_id, # 제품 ID
            'dispCatNo': category # 카테고리 ID
        }
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.102 Safari/537.36'
        }
        resp = requests.get(prd_url, params=params, headers=headers)
        soup = BeautifulSoup(resp.text)

        info = soup.find('div', class_='prd_info')
        prd_name = info.find('p', class_='prd_name').text
        prd_price = info.find('span', class_='price-2').find('strong').text
        
        tag_list = get_tags(prd_id, count_vect) # 제품의 리뷰 태그 리스트
        count_list = tag_count(tag_list) # 태그별 출현 횟수
        top_tags = max_pooling(count_list) # 빈도수가 가장 많은 태그 추출
        
        top_tags_str = ""
        for tag in top_tags: # 태그리스트를 문자열로 변환 => csv 저장시 필요
            top_tags_str = top_tags_str + tag + ' '
        
        
        prd_info = { # 제품 정보
            'id': prd_id, # ID
            'name': prd_name, # 이름
            'price': prd_price, # 가격
            'top_tags': top_tags_str # 상위 6개 태그
        }
        
        result.append(prd_info)
        print("만났지롱")
        
    return result

# %% [markdown]
# ### 제품 리뷰 태그 획득

# %%
# 제품 리뷰 태그 획득 => 태그(필터): 피부타입(지성,복합성,...), 피부톤(...), 피부고민(...)
def get_tags(prd_id, count_vect):
    result = []
    i = 0
    review_url = 'https://www.oliveyoung.co.kr/store/goods/getGdasNewListJson.do'
    filename = 'model/finalized_model.sav'  # 긍부정 판별 모델  # 파일 경로 및 이름 확인 필요
    loaded_model = pickle.load(open(filename, 'rb'))
    
    while True:
        i += 1
        params = {
            'goodsNo': prd_id, # 제품 ID
            'gdasSort': '05', # 정렬: 유용한순
            'pageIdx': i # 페이지 번호
        }
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.102 Safari/537.36'
        }
        resp = requests.get(review_url, params=params, headers=headers)
        review_data = resp.json() # jason data 저장
        review_list = review_data['gdasList'] # 리뷰 데이터 리스트 (한 페이지당 최대 10개의 리뷰 존재)
        
        if len(review_list) == 0: # 마지막 페이지를 넘긴 경우 while문 종료
            break
        
        for review in review_list:
            ################## new: use model ##################
            comment = review['gdasCont'] # 리뷰 내용
            if comment is not None:
                loaded_model = pickle.load(open(filename, 'rb'))
                pd_e = count_vect.transform(list(comment))
                predict = loaded_model.predict(pd_e) # 댓글 긍/부정 예측

                if predict[0] == 1: # 긍정 리뷰의 데이터만 저장

                ################## old : use score ##################
                # score = int(review['gdasScrVal']) / 2 # 리뷰 별점
                # if score >= 5: # 별점 5개짜리 리뷰 정보만 저장
                    try:
                        tags= []
                        for info in review["addInfoNm"]: # 해당 리뷰에 존재하는 모든 태그 저장
                            tags.append(info['mrkNm'])
                        result.append(tags)
                    except:
                        pass
        
    return result

# %% [markdown]
# ### 태그별 출현 횟수

# %%
# 태그별 출현 횟수 
# 기존 preprocessing
def tag_count(tag_list):
    # INPUT EX)
    #     [
    #         ["복합성","쿨톤","잡티","미백","주름","각질"],
    #         ["건성","웜톤","트러블","블랙헤드"], ...
    #     ]
    # base_list : Back Of Words
    name_list = ["복합성","건성","지성","쿨톤","웜톤","잡티","미백","주름","각질","트러블","블랙헤드", \
                 "피지과다","민감성","모공","탄력","홍조","아토피"]
    result = [0 for i in range(len(name_list))] # zeros matrix for counting frequency
    for tags in tag_list:
        for tag in tags:
            index = name_list.index(tag)
            result[index] += 1
    # 단어수를 세서 반환
    # OUTPUT EX) [7, 20, 3, 10, 19, 14, 13, 15, 11, 15, 12, 6, 16, 13, 14, 6, 3]
    return result

# %% [markdown]
# ### 빈도수가 가장 많은 태그 추출

# %%
def max_pooling(tag_count):
    #카테고리별로 빈도수가 가장 많은 키워드 추출
    # 피부 성격 = ["복합성","건성","지성"] 중에 1개
    # 피부 빛 = ["쿨톤","웜톤"] 중에 1개
    # 피부 트러블 = ["잡티","미백","주름","각질","트러블","블랙헤드","피지과다","민감성","모공","탄력","홍조","아토피"] 중에 4개
    import random
    
    name_list=["복합성","건성","지성","쿨톤","웜톤","잡티","미백","주름","각질","트러블","블랙헤드", \
               "피지과다","민감성","모공","탄력","홍조","아토피"]
    
    try:
        max_1=max(tag_count[0:3])
        index_1 = tag_count[0:3].index(max_1)
        sol_1 = name_list[index_1]
    except:
        sol_1='복합성'
    
    try:
        max_2=max(tag_count[3:5])
        index_2 = tag_count[3:5].index(max_2)+3
        sol_2 = name_list[index_2]
    except:
        sol_2='웜톤'
    result=[]
    result.append(sol_1)
    result.append(sol_2)
    temp_list=[]
    for i in zip(name_list[5:-1],tag_count[5:-1]):
        temp_list.append(i)
    new_temp_list = sorted(temp_list, key=lambda temp_list: temp_list[1],reverse=True)

    for k in range(4):
        try:    
            result.append(new_temp_list[k][0])
        except:
            shuffle_list = random.shuffle(name_list[5:-1])
            result.extend(shuffle_list[0:4])
    #OUTPUT EX)
    #   ['건성', '웜톤', '민감성', '주름', '트러블', '잡티']
    
    return result

# %% [markdown]
# ### csv 파일로 저장

# %%
# csv 파일로 저장
def save(category, result):
    import pandas as pd
    file_name = 'data/' + category + '.csv'
    data = pd.DataFrame(result)    
    data.to_csv(file_name)

# %% [markdown]
# ### 전체 저장

# %%
# 전체 저장
def save_all():
    category_ids = ['1000001000100010001', '1000001000100010002', '1000001000100010003','1000001000100010011', '1000001000100010004']
    for category in category_ids:
        prd_list = get_items(category)
        result = get_items_info(prd_list, category)
        save(category, result)

# %% [markdown]
# ### 카테고리 코드별 이름
#
# category_name = ['스킨/토너', '로션', '에센스/세럼', '앰플', '크림']
#
# category_ids = ['1000001000100010001', '1000001000100010002', '1000001000100010003', '1000001000100010011', '1000001000100010004']

# %% [markdown]
# ### 수정 필요
# import
#
# get_tags 함수 => model 파일명, 벡터라이징 함수
#
# 벡터라이징 함수 추가

# %%
save_all()
# Out:
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
# 만났지롱
